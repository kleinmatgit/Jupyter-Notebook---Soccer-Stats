# %% [markdown]
# # Introduction

# %% [markdown]
# The goal of this notebook is to analyse worldfootball.net urls and save down results page into tree structure. This will be used later on to get results and save it under a more readable format (csv).
#
# The trees will be saved on the drive under a specific folder hierarchy:
# zone -> competition -> season -> stage.html
#
# for instance:
# france -> ligue1 -> 2016-2017 -> Week01.html
#
# Stage name is then the tree file name.

# %% [markdown]
# # Import

# %%
import lxml.html as lh
import lxml.etree as et
from selenium import webdriver
import time
import pickle
import traceback
import logging
import os.path
import configparser
import os
import re
import datetime

# %% [markdown]
# # Params

# %%
root_path = 'L:/Dev/Sandbox/Apps Development/SoccerWebApp/PySoccer/WorldFootballDotNet/'
conf_path = os.path.join(root_path, '_conf','worldfootball.ini')
log_path = os.path.join(root_path, '_logs')
website_url = 'https://www.worldfootball.net'

# %% [markdown]
# # Logging

# %%
logger = logging.getLogger('myapp')
timestamp = datetime.datetime.now().strftime('%H%M%S')
hdlr = logging.FileHandler(os.path.join(log_path,'worldfootballnet_TreeSaver_' + timestamp + '.log'))
formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
hdlr.setFormatter(formatter)
logger.addHandler(hdlr) 
logger.setLevel(logging.DEBUG)

# %%
def logWrapper(message, level="info", print_console=True):
    if(print_console):
        print(message)
    if(level=="info"):
        logger.info(message)
    elif(level=="warning"):
        logger.warning(message)
    elif(level=="debug"):
        logger.debug(message)
    elif(level=="error"):
        logger.error(message)

# %%
#logger.error("test error")
#logger.warning("this is a warning")
#logger.info("this is just info")
#logger.debug("this is debug")
#logWrapper('hello world')
#logWrapper('message')

# %% [markdown]
# # Conf

# %%
class ConfHandler():

    dicSections = {}
    
    def __init__(self,file_full_path):

        if not os.path.exists(file_full_path):
            raise Exception('path not correct: {0}'.format(file_full_path))
        
        config = configparser.ConfigParser()
        config.read(file_full_path)
        
        for s in config.sections():
            dicParams = {}
            for p in config[s]:
                dicParams[p] = config[s][p]
            self.dicSections[s] = dicParams

    def get(self,section,param, is_param_list = False):
        if(is_param_list):
            return self.dicSections[section][param].replace(' ','').split(',')
        return self.dicSections[section][param]
    
    def get_section(self,section):
        return self.dicSections[section]
    
    def get_sections(self):
        return sorted(list(self.dicSections.keys()))

# %%
# test conf
#conf = ConfHandler(conf_path)
#print(conf.get('france','ligue1'))
#dic = conf.get_section('france')
#print(dic)
#sections = conf.get_sections()
#print(sections)
#print(conf.get('cup', 'club_cup_list', True))

# %% [markdown]
# # Functions

# %% [markdown]
# ## [selenium_url_to_tree] download url final output as a tree

# %%
# get url html as elementtree using selenium.webdriver
def selenium_url_to_tree(driver, url):
    driver.get(url)
    time.sleep(2)
    htmlSource = driver.page_source
    tree = lh.fromstring(htmlSource)
    return tree

# HOW IT WORKS....
# open driver: that will open firefox window
#driver = webdriver.Firefox()

# construct the trees only once
#results_tree = selenium_url_to_tree(driver,week_url)

# close firefox window once done
#driver.quit()

# %%
# return html page as a tree.
# the tree object will be cached to drive so next call won't require web call
def get_tree_from_url(driver, filename, url):
    
    # file doesn't exist, we will have to do a web call
    if(not os.path.isfile(filename)):
        
        # create folder if not done already
        if not os.path.exists(os.path.dirname(filename)):
            try:
                os.makedirs(os.path.dirname(filename))
            except OSError as exc: # Guard against race condition
                if exc.errno != errno.EEXIST:
                    raise
        
        # load up url in web browser
        tree = selenium_url_to_tree(driver,url)
        
        # save it down to the drive
        tree.getroottree().write(filename)
        
        if(not os.path.isfile(filename)):
            raise
        
    # return the loaded tree
    return lh.fromstring(open(filename, 'r').read())

# %%
def get_result_url_from_tree(tree):
    return tree.find('.//div[@class="navibox2"]//div[@class="data"]/ul[2]/li/a').attrib['href']

# %%
# construct dictionary of {season: url}
def get_seasons_dic_from_tree(tree):
    options = tree.findall('.//select[@name="saison"]/option')
    dic = {}
    for option in options:
        season = option.text_content().replace('/','-')
        dic[season] = option.attrib['value']
    return dic

# %%
# construct dictionary of {stage: url}
def get_stages_dic_from_tree(tree):
    
    dic = {}
    
    is_cup = False
    
    # assume we are looking at a 'league' tree
    options = tree.findall('.//select[@name="runde"]/option')
    
    if len(options) == 0:
        # now trying to see if we are looking at a 'cup' tree
        options = tree.findall('.//select[@name="phase"]/option')
        
        if len(options) == 0:
            raise
        else:
            is_cup = True
    
    for option in options:
        stage = option.text_content()
        if(is_cup):
            dic[stage] = option.attrib['value']
        else:
            stage = stage[:stage.find('.')]
            dic['Week' + str('%02d' % int(stage))] = option.attrib['value']
    return dic

# %%
# use regex to find season in an url (ie: 2016-2017)
def match_season(url):
    matchObj = re.match(r'.*([1-3][0-9]{3}-[1-3][0-9]{3}).*', url)
    if not matchObj:
        # sometime we get only year instead of season
        matchObj = re.match(r'.*([1-3][0-9]{3}).*', url)
        if not matchObj:
            raise
    return matchObj.group(1)

# %%
# use regex to find stage in an url (ie: '1' or '38' or 'final')
def match_stage_in_url(url):
    
    # league url
    matchObj = re.match(r'.*[1-3][0-9]{3}-[1-3][0-9]{3}-spieltag/(\b\d{1,2}\b)/', url)
    if matchObj:
        return 'Week' + str('%02d' % int(matchObj.group(1)))
    
    # qualification url: https://www.worldfootball.net/schedule/wm-quali-suedamerika-2010-spieltag/18/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-spieltag/(\b\d{1,2}\b)/', url)
    if matchObj:
        return 'Week' + str('%02d' % int(matchObj.group(1)))
    
    # round url: 
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)-runde/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Round ' + matchObj.group(1).upper()
    
    # group url: https://www.worldfootball.net/schedule/wm-quali-europa-2016-2017-gruppe-a/0/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-gruppe-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Group ' + matchObj.group(1).upper()
    
    # round group url: https://www.worldfootball.net/schedule/wm-quali-asien-2015-2017-3-runde-gruppe-a/2/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)-runde-gruppe-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Round {0} Group {1}'.format(matchObj.group(1).upper(), matchObj.group(2).upper())
    
    # relegation url: https://www.worldfootball.net/schedule/wm-quali-asien-2011-2013-relegation/2/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-relegation/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Relegation'
    
    # cup url: final
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        stage = matchObj.group(1)
        if('finale' in stage or 'endspiel' in stage or 'endrunde' in stage or 'finalrunde' in stage):
            return 'Final'
        elif('entscheidungsspiel' in stage):
            return 'Replays'
        else:
            raise ValueError("Couldn't match stage name in url: {0}".format(url))

# %%
# return selected stage from the tree
def get_selected_stage_from_tree(tree):
    option = tree.find('.//select[@name="runde"]/option[@class="wahl"]')
    stage = option.text_content()[:option.text_content().find('.')]
    return 'Week' + str('%02d' % int(stage))

# %%
def check_stage_name(stage):
    
    stage_allowed_names = ['Week%%', 'Final', 'Semi-finals', 'Quarter-finals', 'Round %%', 'Round of%%', 'Group%%', '3rd place', 'Relegation']
    
    for pattern in stage_allowed_names:
        if('%%' in pattern):
            if pattern.replace('%%','') in stage:
                return
        else:
            if pattern == stage:
                return
    raise ValueError('stage name not allowed: {0}'.format(stage))

# %%
check_stage_name('Group A')
check_stage_name('Round of 16')
check_stage_name('3rd place')

# %%
def format_stage_name(stage):
    dic = {
        '3td place': '3rd place',
        'Third place': '3rd place',
        'Final round': 'Final',
        'Caribbean Quarter-finals': 'Quarter-finals',
        'Caribbean Semi-finals': 'Semi-finals',
        'Caribbean Final': 'Final'
        
    }
    
    if(stage in dic.keys()):
        return dic[stage]
    return stage

# %%
# run the whole tree saver process
def run_tree_saver(conf):

    sections = conf.get_sections()
    ignore_sections = conf.get('general', 'ignore_sections', True)
    #club_cup_list = conf.get('general', 'club_cup_list', True)
    season_min = int(conf.get('general', 'season_min'))
    season_max = int(conf.get('general', 'season_max'))
    
    # open driver
    driver = webdriver.Firefox()

    for section in sections:

        if(section in ignore_sections):
            continue
        
        logWrapper('##########################################################')
        logWrapper('processing section {0}'.format(section))
        logWrapper('##########################################################')
        
        dic = conf.get_section(section)

        for competition in dic.keys():

            logWrapper('**********************************************')
            logWrapper('processing competition {0}'.format(competition))
            logWrapper('**********************************************')
            
            # competition overview url
            ovw_url = website_url + '/competition/' + dic[competition] + '/'

            competition_path = os.path.join(root_path, section, competition)

            # get tree associated to overview url (from drive or from web)
            ovw_tree_file_full_path = os.path.join(competition_path, competition + '_overview.html')
            ovw_tree = get_tree_from_url(driver, ovw_tree_file_full_path, ovw_url)

            # get result url from overview url, that's the current result url (ie: current season, current stage)
            curr_result_url = website_url + get_result_url_from_tree(ovw_tree)

            # get tree associated to current result url
            curr_tree_full_path = os.path.join(competition_path, competition + '_current_result.html')
            curr_tree = get_tree_from_url(driver, curr_tree_full_path , curr_result_url)

            # get dic {season:url} from current result tree
            dic_seasons = get_seasons_dic_from_tree(curr_tree)
            
            for season in dic_seasons.keys():

                try:
                    # check if we process this season (ie: not too old)
                    if(int(season[:4]) < season_min or int(season[:4]) > season_max):
                        logWrapper('ignoring season {0}'.format(season))
                        continue
                    
                    logWrapper('--------------------------------')
                    logWrapper('processing season {0}'.format(season))
                    logWrapper('--------------------------------')
                    
                    season_path = os.path.join(competition_path, season)
                    
                    # default url when season is loaded, usually the final stage or last week of a season
                    season_default_url = website_url + dic_seasons[season]
                    season_default_full_path = os.path.join(season_path, 'season_default.html')
                    last_stage_tree = get_tree_from_url(driver, season_default_full_path , season_default_url)
                                        
                    # this url is usually the last stage url for a given season (or the 'final' url for a cup competition)
                    #stage_url = website_url + dic_seasons[season]
                    #logWrapper('stage url: {0}'.format(stage_url))
                    # get stage from the url itself
                    #stage = match_stage_in_url(stage_url)
                    #check_stage_name(stage)
                    #logWrapper('stage: {0}'.format(stage))                    
                    
                    # get tree associated to season last stage url
                    #last_stage_full_path = os.path.join(season_path, stage + '.html')
                    #last_stage_tree = get_tree_from_url(driver, last_stage_full_path , stage_url)
                    
                    # get dic {stage:url} from last stage tree
                    dic_stages = get_stages_dic_from_tree(last_stage_tree)

                    for stage_as_in_url in dic_stages.keys():

                        try:
                            #stage = format_stage_name(stage_as_in_url)
                            #check_stage_name(stage)
                            
                            logWrapper('processing {0}, season {1}, stage {2}'.format(competition, season, stage_as_in_url))

                            # this url is usually the last stage url for a given season (or the 'final' url for a cup competition)
                            curr_stage_url = website_url + dic_stages[stage_as_in_url]
                            #logWrapper('we are looking for this url: {0}'.format(curr_stage_url))

                            # get tree associated to current stage url
                            curr_stage_full_path = os.path.join(season_path, stage_as_in_url + '.html')
                            #logWrapper('should resolve to path: {0}'.format(curr_stage_full_path))

                            last_stage_tree = get_tree_from_url(driver, curr_stage_full_path , curr_stage_url)
                        except Exception as e:
                            logWrapper("Exception while processing stage {0}: {1}".format(stage, e), level='error')
                            continue
                    
                except Exception as e:
                    logWrapper("Exception while processing season {0}: {1}".format(season, e), level='error')
                    continue
                
    # close driver
    driver.quit()
    logWrapper("Process finished")

# %%
# load conf
conf = ConfHandler(conf_path)
run_tree_saver(conf)
# Out:
# ##########################################################
# processing section portugal
# ##########################################################
# **********************************************
# processing competition primeira-liga
# **********************************************
# --------------------------------
# processing season 2017-2018
# --------------------------------
# processing primeira-liga, season 2017-2018, stage Week01
# processing primeira-liga, season 2017-2018, stage Week02
# processing primeira-liga, season 2017-2018, stage Week03
# processing primeira-liga, season 2017-2018, stage Week04
# processing primeira-liga, season 2017-2018, stage Week05
# processing primeira-liga, season 2017-2018, stage Week06
# processing primeira-liga, season 2017-2018, stage Week07
# processing primeira-liga, season 2017-2018, stage Week08
# processing primeira-liga, season 2017-2018, stage Week09
# processing primeira-liga, season 2017-2018, stage Week10
# processing primeira-liga, season 2017-2018, stage Week11
# processing primeira-liga, season 2017-2018, stage Week12
# processing primeira-liga, season 2017-2018, stage Week13
# processing primeira-liga, season 2017-2018, stage Week14
# processing primeira-liga, season 2017-2018, stage Week15
# processing primeira-liga, season 2017-2018, stage Week16
# processing primeira-liga, season 2017-2018, stage Week17
# processing primeira-liga, season 2017-2018, stage Week18
# processing primeira-liga, season 2017-2018, stage Week19
# processing primeira-liga, season 2017-2018, stage Week20
# processing primeira-liga, season 2017-2018, stage Week21
# processing primeira-liga, season 2017-2018, stage Week22
# processing primeira-liga, season 2017-2018, stage Week23
# processing primeira-liga, season 2017-2018, stage Week24
# processing primeira-liga, season 2017-2018, stage Week25
# processing primeira-liga, season 2017-2018, stage Week26
# processing primeira-liga, season 2017-2018, stage Week27
# processing primeira-liga, season 2017-2018, stage Week28
# processing primeira-liga, season 2017-2018, stage Week29
# processing primeira-liga, season 2017-2018, stage Week30
# processing primeira-liga, season 2017-2018, stage Week31
# processing primeira-liga, season 2017-2018, stage Week32
# processing primeira-liga, season 2017-2018, stage Week33
# processing primeira-liga, season 2017-2018, stage Week34
# --------------------------------
# processing season 2016-2017
# --------------------------------
# processing primeira-liga, season 2016-2017, stage Week01
# processing primeira-liga, season 2016-2017, stage Week02
# processing primeira-liga, season 2016-2017, stage Week03
# processing primeira-liga, season 2016-2017, stage Week04
# processing primeira-liga, season 2016-2017, stage Week05
# processing primeira-liga, season 2016-2017, stage Week06
# processing primeira-liga, season 2016-2017, stage Week07
# processing primeira-liga, season 2016-2017, stage Week08
# processing primeira-liga, season 2016-2017, stage Week09
# processing primeira-liga, season 2016-2017, stage Week10
# processing primeira-liga, season 2016-2017, stage Week11
# processing primeira-liga, season 2016-2017, stage Week12
# processing primeira-liga, season 2016-2017, stage Week13
# processing primeira-liga, season 2016-2017, stage Week14
# processing primeira-liga, season 2016-2017, stage Week15
# processing primeira-liga, season 2016-2017, stage Week16
# processing primeira-liga, season 2016-2017, stage Week17
# processing primeira-liga, season 2016-2017, stage Week18
# processing primeira-liga, season 2016-2017, stage Week19
# processing primeira-liga, season 2016-2017, stage Week20
# processing primeira-liga, season 2016-2017, stage Week21
# processing primeira-liga, season 2016-2017, stage Week22
# processing primeira-liga, season 2016-2017, stage Week23
# processing primeira-liga, season 2016-2017, stage Week24
# processing primeira-liga, season 2016-2017, stage Week25
# processing primeira-liga, season 2016-2017, stage Week26
# processing primeira-liga, season 2016-2017, stage Week27
# processing primeira-liga, season 2016-2017, stage Week28
# processing primeira-liga, season 2016-2017, stage Week29
# processing primeira-liga, season 2016-2017, stage Week30
# processing primeira-liga, season 2016-2017, stage Week31
# processing primeira-liga, season 2016-2017, stage Week32
# processing primeira-liga, season 2016-2017, stage Week33
# processing primeira-liga, season 2016-2017, stage Week34
# --------------------------------
# processing season 2015-2016
# --------------------------------
# processing primeira-liga, season 2015-2016, stage Week01
# processing primeira-liga, season 2015-2016, stage Week02
# processing primeira-liga, season 2015-2016, stage Week03
# processing primeira-liga, season 2015-2016, stage Week04
# processing primeira-liga, season 2015-2016, stage Week05
# processing primeira-liga, season 2015-2016, stage Week06
# processing primeira-liga, season 2015-2016, stage Week07
# processing primeira-liga, season 2015-2016, stage Week08
# processing primeira-liga, season 2015-2016, stage Week09
# processing primeira-liga, season 2015-2016, stage Week10
# processing primeira-liga, season 2015-2016, stage Week11
# processing primeira-liga, season 2015-2016, stage Week12
# processing primeira-liga, season 2015-2016, stage Week13
# processing primeira-liga, season 2015-2016, stage Week14
# processing primeira-liga, season 2015-2016, stage Week15
# processing primeira-liga, season 2015-2016, stage Week16
# processing primeira-liga, season 2015-2016, stage Week17
# processing primeira-liga, season 2015-2016, stage Week18
# processing primeira-liga, season 2015-2016, stage Week19
# processing primeira-liga, season 2015-2016, stage Week20
# processing primeira-liga, season 2015-2016, stage Week21
# processing primeira-liga, season 2015-2016, stage Week22
# processing primeira-liga, season 2015-2016, stage Week23
# processing primeira-liga, season 2015-2016, stage Week24
# processing primeira-liga, season 2015-2016, stage Week25
# processing primeira-liga, season 2015-2016, stage Week26
# processing primeira-liga, season 2015-2016, stage Week27
# processing primeira-liga, season 2015-2016, stage Week28
# processing primeira-liga, season 2015-2016, stage Week29
# processing primeira-liga, season 2015-2016, stage Week30
# processing primeira-liga, season 2015-2016, stage Week31
# processing primeira-liga, season 2015-2016, stage Week32
# processing primeira-liga, season 2015-2016, stage Week33
# processing primeira-liga, season 2015-2016, stage Week34
# --------------------------------
# processing season 2014-2015
# --------------------------------
# processing primeira-liga, season 2014-2015, stage Week01
# processing primeira-liga, season 2014-2015, stage Week02
# processing primeira-liga, season 2014-2015, stage Week03
# processing primeira-liga, season 2014-2015, stage Week04
# processing primeira-liga, season 2014-2015, stage Week05
# processing primeira-liga, season 2014-2015, stage Week06
# processing primeira-liga, season 2014-2015, stage Week07
# processing primeira-liga, season 2014-2015, stage Week08
# processing primeira-liga, season 2014-2015, stage Week09
# processing primeira-liga, season 2014-2015, stage Week10
# processing primeira-liga, season 2014-2015, stage Week11
# processing primeira-liga, season 2014-2015, stage Week12
# processing primeira-liga, season 2014-2015, stage Week13
# processing primeira-liga, season 2014-2015, stage Week14
# processing primeira-liga, season 2014-2015, stage Week15
# processing primeira-liga, season 2014-2015, stage Week16
# processing primeira-liga, season 2014-2015, stage Week17
# processing primeira-liga, season 2014-2015, stage Week18
# processing primeira-liga, season 2014-2015, stage Week19
# processing primeira-liga, season 2014-2015, stage Week20
# processing primeira-liga, season 2014-2015, stage Week21
# processing primeira-liga, season 2014-2015, stage Week22
# processing primeira-liga, season 2014-2015, stage Week23
# processing primeira-liga, season 2014-2015, stage Week24
# processing primeira-liga, season 2014-2015, stage Week25
# processing primeira-liga, season 2014-2015, stage Week26
# processing primeira-liga, season 2014-2015, stage Week27
# processing primeira-liga, season 2014-2015, stage Week28
# processing primeira-liga, season 2014-2015, stage Week29
# processing primeira-liga, season 2014-2015, stage Week30
# processing primeira-liga, season 2014-2015, stage Week31
# processing primeira-liga, season 2014-2015, stage Week32
# processing primeira-liga, season 2014-2015, stage Week33
# processing primeira-liga, season 2014-2015, stage Week34
# --------------------------------
# processing season 2013-2014
# --------------------------------
# processing primeira-liga, season 2013-2014, stage Week01
# processing primeira-liga, season 2013-2014, stage Week02
# processing primeira-liga, season 2013-2014, stage Week03
# processing primeira-liga, season 2013-2014, stage Week04
# processing primeira-liga, season 2013-2014, stage Week05
# processing primeira-liga, season 2013-2014, stage Week06
# processing primeira-liga, season 2013-2014, stage Week07
# processing primeira-liga, season 2013-2014, stage Week08
# processing primeira-liga, season 2013-2014, stage Week09
# processing primeira-liga, season 2013-2014, stage Week10
# processing primeira-liga, season 2013-2014, stage Week11
# processing primeira-liga, season 2013-2014, stage Week12
# processing primeira-liga, season 2013-2014, stage Week13
# processing primeira-liga, season 2013-2014, stage Week14
# processing primeira-liga, season 2013-2014, stage Week15
# processing primeira-liga, season 2013-2014, stage Week16
# processing primeira-liga, season 2013-2014, stage Week17
# processing primeira-liga, season 2013-2014, stage Week18
# processing primeira-liga, season 2013-2014, stage Week19
# processing primeira-liga, season 2013-2014, stage Week20
# processing primeira-liga, season 2013-2014, stage Week21
# processing primeira-liga, season 2013-2014, stage Week22
# processing primeira-liga, season 2013-2014, stage Week23
# processing primeira-liga, season 2013-2014, stage Week24
# processing primeira-liga, season 2013-2014, stage Week25
# processing primeira-liga, season 2013-2014, stage Week26
# processing primeira-liga, season 2013-2014, stage Week27
# processing primeira-liga, season 2013-2014, stage Week28
# processing primeira-liga, season 2013-2014, stage Week29
# processing primeira-liga, season 2013-2014, stage Week30
# --------------------------------
# processing season 2012-2013
# --------------------------------
# processing primeira-liga, season 2012-2013, stage Week01
# processing primeira-liga, season 2012-2013, stage Week02
# processing primeira-liga, season 2012-2013, stage Week03
# processing primeira-liga, season 2012-2013, stage Week04
# processing primeira-liga, season 2012-2013, stage Week05
# processing primeira-liga, season 2012-2013, stage Week06
# processing primeira-liga, season 2012-2013, stage Week07
# processing primeira-liga, season 2012-2013, stage Week08
# processing primeira-liga, season 2012-2013, stage Week09
# processing primeira-liga, season 2012-2013, stage Week10
# processing primeira-liga, season 2012-2013, stage Week11
# processing primeira-liga, season 2012-2013, stage Week12
# processing primeira-liga, season 2012-2013, stage Week13
# processing primeira-liga, season 2012-2013, stage Week14
# processing primeira-liga, season 2012-2013, stage Week15
# processing primeira-liga, season 2012-2013, stage Week16
# processing primeira-liga, season 2012-2013, stage Week17
# processing primeira-liga, season 2012-2013, stage Week18
# processing primeira-liga, season 2012-2013, stage Week19
# processing primeira-liga, season 2012-2013, stage Week20
# processing primeira-liga, season 2012-2013, stage Week21
# processing primeira-liga, season 2012-2013, stage Week22
# processing primeira-liga, season 2012-2013, stage Week23
# processing primeira-liga, season 2012-2013, stage Week24
# processing primeira-liga, season 2012-2013, stage Week25
# processing primeira-liga, season 2012-2013, stage Week26
# processing primeira-liga, season 2012-2013, stage Week27
# processing primeira-liga, season 2012-2013, stage Week28
# processing primeira-liga, season 2012-2013, stage Week29
# processing primeira-liga, season 2012-2013, stage Week30
# --------------------------------
# processing season 2011-2012
# --------------------------------
# processing primeira-liga, season 2011-2012, stage Week01
# processing primeira-liga, season 2011-2012, stage Week02
# processing primeira-liga, season 2011-2012, stage Week03
# processing primeira-liga, season 2011-2012, stage Week04
# processing primeira-liga, season 2011-2012, stage Week05
# processing primeira-liga, season 2011-2012, stage Week06
# processing primeira-liga, season 2011-2012, stage Week07
# processing primeira-liga, season 2011-2012, stage Week08
# processing primeira-liga, season 2011-2012, stage Week09
# processing primeira-liga, season 2011-2012, stage Week10
# processing primeira-liga, season 2011-2012, stage Week11
# processing primeira-liga, season 2011-2012, stage Week12
# processing primeira-liga, season 2011-2012, stage Week13
# processing primeira-liga, season 2011-2012, stage Week14
# processing primeira-liga, season 2011-2012, stage Week15
# processing primeira-liga, season 2011-2012, stage Week16
# processing primeira-liga, season 2011-2012, stage Week17
# processing primeira-liga, season 2011-2012, stage Week18
# processing primeira-liga, season 2011-2012, stage Week19
# processing primeira-liga, season 2011-2012, stage Week20
# processing primeira-liga, season 2011-2012, stage Week21
# processing primeira-liga, season 2011-2012, stage Week22
# processing primeira-liga, season 2011-2012, stage Week23
# processing primeira-liga, season 2011-2012, stage Week24
# processing primeira-liga, season 2011-2012, stage Week25
# processing primeira-liga, season 2011-2012, stage Week26
# processing primeira-liga, season 2011-2012, stage Week27
# processing primeira-liga, season 2011-2012, stage Week28
# processing primeira-liga, season 2011-2012, stage Week29
# processing primeira-liga, season 2011-2012, stage Week30
# --------------------------------
# processing season 2010-2011
# --------------------------------
# processing primeira-liga, season 2010-2011, stage Week01
# processing primeira-liga, season 2010-2011, stage Week02
# processing primeira-liga, season 2010-2011, stage Week03
# processing primeira-liga, season 2010-2011, stage Week04
# processing primeira-liga, season 2010-2011, stage Week05
# processing primeira-liga, season 2010-2011, stage Week06
# processing primeira-liga, season 2010-2011, stage Week07
# processing primeira-liga, season 2010-2011, stage Week08
# processing primeira-liga, season 2010-2011, stage Week09
# processing primeira-liga, season 2010-2011, stage Week10
# processing primeira-liga, season 2010-2011, stage Week11
# processing primeira-liga, season 2010-2011, stage Week12
# processing primeira-liga, season 2010-2011, stage Week13
# processing primeira-liga, season 2010-2011, stage Week14
# processing primeira-liga, season 2010-2011, stage Week15
# processing primeira-liga, season 2010-2011, stage Week16
# processing primeira-liga, season 2010-2011, stage Week17
# processing primeira-liga, season 2010-2011, stage Week18
# processing primeira-liga, season 2010-2011, stage Week19
# processing primeira-liga, season 2010-2011, stage Week20
# processing primeira-liga, season 2010-2011, stage Week21
# processing primeira-liga, season 2010-2011, stage Week22
# processing primeira-liga, season 2010-2011, stage Week23
# processing primeira-liga, season 2010-2011, stage Week24
# processing primeira-liga, season 2010-2011, stage Week25
# processing primeira-liga, season 2010-2011, stage Week26
# processing primeira-liga, season 2010-2011, stage Week27
# processing primeira-liga, season 2010-2011, stage Week28
# processing primeira-liga, season 2010-2011, stage Week29
# processing primeira-liga, season 2010-2011, stage Week30
# --------------------------------
# processing season 2009-2010
# --------------------------------
# processing primeira-liga, season 2009-2010, stage Week01
# processing primeira-liga, season 2009-2010, stage Week02
# processing primeira-liga, season 2009-2010, stage Week03
# processing primeira-liga, season 2009-2010, stage Week04
# processing primeira-liga, season 2009-2010, stage Week05
# processing primeira-liga, season 2009-2010, stage Week06
# processing primeira-liga, season 2009-2010, stage Week07
# processing primeira-liga, season 2009-2010, stage Week08
# processing primeira-liga, season 2009-2010, stage Week09
# processing primeira-liga, season 2009-2010, stage Week10
# processing primeira-liga, season 2009-2010, stage Week11
# processing primeira-liga, season 2009-2010, stage Week12
# processing primeira-liga, season 2009-2010, stage Week13
# processing primeira-liga, season 2009-2010, stage Week14
# processing primeira-liga, season 2009-2010, stage Week15
# processing primeira-liga, season 2009-2010, stage Week16
# processing primeira-liga, season 2009-2010, stage Week17
# processing primeira-liga, season 2009-2010, stage Week18
# processing primeira-liga, season 2009-2010, stage Week19
# processing primeira-liga, season 2009-2010, stage Week20
# processing primeira-liga, season 2009-2010, stage Week21
# processing primeira-liga, season 2009-2010, stage Week22
# processing primeira-liga, season 2009-2010, stage Week23
# processing primeira-liga, season 2009-2010, stage Week24
# processing primeira-liga, season 2009-2010, stage Week25
# processing primeira-liga, season 2009-2010, stage Week26
# processing primeira-liga, season 2009-2010, stage Week27
# processing primeira-liga, season 2009-2010, stage Week28
# processing primeira-liga, season 2009-2010, stage Week29
# processing primeira-liga, season 2009-2010, stage Week30
# --------------------------------
# processing season 2008-2009
# --------------------------------
# processing primeira-liga, season 2008-2009, stage Week01
# processing primeira-liga, season 2008-2009, stage Week02
# processing primeira-liga, season 2008-2009, stage Week03
# processing primeira-liga, season 2008-2009, stage Week04
# processing primeira-liga, season 2008-2009, stage Week05
# processing primeira-liga, season 2008-2009, stage Week06
# processing primeira-liga, season 2008-2009, stage Week07
# processing primeira-liga, season 2008-2009, stage Week08
# processing primeira-liga, season 2008-2009, stage Week09
# processing primeira-liga, season 2008-2009, stage Week10
# processing primeira-liga, season 2008-2009, stage Week11
# processing primeira-liga, season 2008-2009, stage Week12
# processing primeira-liga, season 2008-2009, stage Week13
# processing primeira-liga, season 2008-2009, stage Week14
# processing primeira-liga, season 2008-2009, stage Week15
# processing primeira-liga, season 2008-2009, stage Week16
# processing primeira-liga, season 2008-2009, stage Week17
# processing primeira-liga, season 2008-2009, stage Week18
# processing primeira-liga, season 2008-2009, stage Week19
# processing primeira-liga, season 2008-2009, stage Week20
# processing primeira-liga, season 2008-2009, stage Week21
# processing primeira-liga, season 2008-2009, stage Week22
# processing primeira-liga, season 2008-2009, stage Week23
# processing primeira-liga, season 2008-2009, stage Week24
# processing primeira-liga, season 2008-2009, stage Week25
# processing primeira-liga, season 2008-2009, stage Week26
# processing primeira-liga, season 2008-2009, stage Week27
# processing primeira-liga, season 2008-2009, stage Week28
# processing primeira-liga, season 2008-2009, stage Week29
# processing primeira-liga, season 2008-2009, stage Week30
# --------------------------------
# processing season 2007-2008
# --------------------------------
# processing primeira-liga, season 2007-2008, stage Week01
# processing primeira-liga, season 2007-2008, stage Week02
# processing primeira-liga, season 2007-2008, stage Week03
# processing primeira-liga, season 2007-2008, stage Week04
# processing primeira-liga, season 2007-2008, stage Week05
# processing primeira-liga, season 2007-2008, stage Week06
# processing primeira-liga, season 2007-2008, stage Week07
# processing primeira-liga, season 2007-2008, stage Week08
# processing primeira-liga, season 2007-2008, stage Week09
# processing primeira-liga, season 2007-2008, stage Week10
# processing primeira-liga, season 2007-2008, stage Week11
# processing primeira-liga, season 2007-2008, stage Week12
# processing primeira-liga, season 2007-2008, stage Week13
# processing primeira-liga, season 2007-2008, stage Week14
# processing primeira-liga, season 2007-2008, stage Week15
# processing primeira-liga, season 2007-2008, stage Week16
# processing primeira-liga, season 2007-2008, stage Week17
# processing primeira-liga, season 2007-2008, stage Week18
# processing primeira-liga, season 2007-2008, stage Week19
# processing primeira-liga, season 2007-2008, stage Week20
# processing primeira-liga, season 2007-2008, stage Week21
# processing primeira-liga, season 2007-2008, stage Week22
# processing primeira-liga, season 2007-2008, stage Week23
# processing primeira-liga, season 2007-2008, stage Week24
# processing primeira-liga, season 2007-2008, stage Week25
# processing primeira-liga, season 2007-2008, stage Week26
# processing primeira-liga, season 2007-2008, stage Week27
# processing primeira-liga, season 2007-2008, stage Week28
# processing primeira-liga, season 2007-2008, stage Week29
# processing primeira-liga, season 2007-2008, stage Week30
# --------------------------------
# processing season 2006-2007
# --------------------------------
# processing primeira-liga, season 2006-2007, stage Week01
# processing primeira-liga, season 2006-2007, stage Week02
# processing primeira-liga, season 2006-2007, stage Week03
# processing primeira-liga, season 2006-2007, stage Week04
# processing primeira-liga, season 2006-2007, stage Week05
# processing primeira-liga, season 2006-2007, stage Week06
# processing primeira-liga, season 2006-2007, stage Week07
# processing primeira-liga, season 2006-2007, stage Week08
# processing primeira-liga, season 2006-2007, stage Week09
# processing primeira-liga, season 2006-2007, stage Week10
# processing primeira-liga, season 2006-2007, stage Week11
# processing primeira-liga, season 2006-2007, stage Week12
# processing primeira-liga, season 2006-2007, stage Week13
# processing primeira-liga, season 2006-2007, stage Week14
# processing primeira-liga, season 2006-2007, stage Week15
# processing primeira-liga, season 2006-2007, stage Week16
# processing primeira-liga, season 2006-2007, stage Week17
# processing primeira-liga, season 2006-2007, stage Week18
# processing primeira-liga, season 2006-2007, stage Week19
# processing primeira-liga, season 2006-2007, stage Week20
# processing primeira-liga, season 2006-2007, stage Week21
# processing primeira-liga, season 2006-2007, stage Week22
# processing primeira-liga, season 2006-2007, stage Week23
# processing primeira-liga, season 2006-2007, stage Week24
# processing primeira-liga, season 2006-2007, stage Week25
# processing primeira-liga, season 2006-2007, stage Week26
# processing primeira-liga, season 2006-2007, stage Week27
# processing primeira-liga, season 2006-2007, stage Week28
# processing primeira-liga, season 2006-2007, stage Week29
# processing primeira-liga, season 2006-2007, stage Week30
# --------------------------------
# processing season 2005-2006
# --------------------------------
# processing primeira-liga, season 2005-2006, stage Week01
# processing primeira-liga, season 2005-2006, stage Week02
# processing primeira-liga, season 2005-2006, stage Week03
# processing primeira-liga, season 2005-2006, stage Week04
# processing primeira-liga, season 2005-2006, stage Week05
# processing primeira-liga, season 2005-2006, stage Week06
# processing primeira-liga, season 2005-2006, stage Week07
# processing primeira-liga, season 2005-2006, stage Week08
# processing primeira-liga, season 2005-2006, stage Week09
# processing primeira-liga, season 2005-2006, stage Week10
# processing primeira-liga, season 2005-2006, stage Week11
# processing primeira-liga, season 2005-2006, stage Week12
# processing primeira-liga, season 2005-2006, stage Week13
# processing primeira-liga, season 2005-2006, stage Week14
# processing primeira-liga, season 2005-2006, stage Week15
# processing primeira-liga, season 2005-2006, stage Week16
# processing primeira-liga, season 2005-2006, stage Week17
# processing primeira-liga, season 2005-2006, stage Week18
# processing primeira-liga, season 2005-2006, stage Week19
# processing primeira-liga, season 2005-2006, stage Week20
# processing primeira-liga, season 2005-2006, stage Week21
# processing primeira-liga, season 2005-2006, stage Week22
# processing primeira-liga, season 2005-2006, stage Week23
# processing primeira-liga, season 2005-2006, stage Week24
# processing primeira-liga, season 2005-2006, stage Week25
# processing primeira-liga, season 2005-2006, stage Week26
# processing primeira-liga, season 2005-2006, stage Week27
# processing primeira-liga, season 2005-2006, stage Week28
# processing primeira-liga, season 2005-2006, stage Week29
# processing primeira-liga, season 2005-2006, stage Week30
# processing primeira-liga, season 2005-2006, stage Week31
# processing primeira-liga, season 2005-2006, stage Week32
# processing primeira-liga, season 2005-2006, stage Week33
# processing primeira-liga, season 2005-2006, stage Week34
# --------------------------------
# processing season 2004-2005
# --------------------------------
# processing primeira-liga, season 2004-2005, stage Week01
# processing primeira-liga, season 2004-2005, stage Week02
# processing primeira-liga, season 2004-2005, stage Week03
# processing primeira-liga, season 2004-2005, stage Week04
# processing primeira-liga, season 2004-2005, stage Week05
# processing primeira-liga, season 2004-2005, stage Week06
# processing primeira-liga, season 2004-2005, stage Week07
# processing primeira-liga, season 2004-2005, stage Week08
# processing primeira-liga, season 2004-2005, stage Week09
# processing primeira-liga, season 2004-2005, stage Week10
# processing primeira-liga, season 2004-2005, stage Week11
# processing primeira-liga, season 2004-2005, stage Week12
# processing primeira-liga, season 2004-2005, stage Week13
# processing primeira-liga, season 2004-2005, stage Week14
# processing primeira-liga, season 2004-2005, stage Week15
# processing primeira-liga, season 2004-2005, stage Week16
# processing primeira-liga, season 2004-2005, stage Week17
# processing primeira-liga, season 2004-2005, stage Week18
# processing primeira-liga, season 2004-2005, stage Week19
# processing primeira-liga, season 2004-2005, stage Week20
# processing primeira-liga, season 2004-2005, stage Week21
# processing primeira-liga, season 2004-2005, stage Week22
# processing primeira-liga, season 2004-2005, stage Week23
# processing primeira-liga, season 2004-2005, stage Week24
# processing primeira-liga, season 2004-2005, stage Week25
# processing primeira-liga, season 2004-2005, stage Week26
# processing primeira-liga, season 2004-2005, stage Week27
# processing primeira-liga, season 2004-2005, stage Week28
# processing primeira-liga, season 2004-2005, stage Week29
# processing primeira-liga, season 2004-2005, stage Week30
# processing primeira-liga, season 2004-2005, stage Week31
# processing primeira-liga, season 2004-2005, stage Week32
# processing primeira-liga, season 2004-2005, stage Week33
# processing primeira-liga, season 2004-2005, stage Week34
# --------------------------------
# processing season 2003-2004
# --------------------------------
# processing primeira-liga, season 2003-2004, stage Week01
# processing primeira-liga, season 2003-2004, stage Week02
# processing primeira-liga, season 2003-2004, stage Week03
# processing primeira-liga, season 2003-2004, stage Week04
# processing primeira-liga, season 2003-2004, stage Week05
# processing primeira-liga, season 2003-2004, stage Week06
# processing primeira-liga, season 2003-2004, stage Week07
# processing primeira-liga, season 2003-2004, stage Week08
# processing primeira-liga, season 2003-2004, stage Week09
# processing primeira-liga, season 2003-2004, stage Week10
# processing primeira-liga, season 2003-2004, stage Week11
# processing primeira-liga, season 2003-2004, stage Week12
# processing primeira-liga, season 2003-2004, stage Week13
# processing primeira-liga, season 2003-2004, stage Week14
# processing primeira-liga, season 2003-2004, stage Week15
# processing primeira-liga, season 2003-2004, stage Week16
# processing primeira-liga, season 2003-2004, stage Week17
# processing primeira-liga, season 2003-2004, stage Week18
# processing primeira-liga, season 2003-2004, stage Week19
# processing primeira-liga, season 2003-2004, stage Week20
# processing primeira-liga, season 2003-2004, stage Week21
# processing primeira-liga, season 2003-2004, stage Week22
# processing primeira-liga, season 2003-2004, stage Week23
# processing primeira-liga, season 2003-2004, stage Week24
# processing primeira-liga, season 2003-2004, stage Week25
# processing primeira-liga, season 2003-2004, stage Week26
# processing primeira-liga, season 2003-2004, stage Week27
# processing primeira-liga, season 2003-2004, stage Week28
# processing primeira-liga, season 2003-2004, stage Week29
# processing primeira-liga, season 2003-2004, stage Week30
# processing primeira-liga, season 2003-2004, stage Week31
# processing primeira-liga, season 2003-2004, stage Week32
# processing primeira-liga, season 2003-2004, stage Week33
# processing primeira-liga, season 2003-2004, stage Week34
# --------------------------------
# processing season 2002-2003
# --------------------------------
# processing primeira-liga, season 2002-2003, stage Week01
# processing primeira-liga, season 2002-2003, stage Week02
# processing primeira-liga, season 2002-2003, stage Week03
# processing primeira-liga, season 2002-2003, stage Week04
# processing primeira-liga, season 2002-2003, stage Week05
# processing primeira-liga, season 2002-2003, stage Week06
# processing primeira-liga, season 2002-2003, stage Week07
# processing primeira-liga, season 2002-2003, stage Week08
# processing primeira-liga, season 2002-2003, stage Week09
# processing primeira-liga, season 2002-2003, stage Week10
# processing primeira-liga, season 2002-2003, stage Week11
# processing primeira-liga, season 2002-2003, stage Week12
# processing primeira-liga, season 2002-2003, stage Week13
# processing primeira-liga, season 2002-2003, stage Week14
# processing primeira-liga, season 2002-2003, stage Week15
# processing primeira-liga, season 2002-2003, stage Week16
# processing primeira-liga, season 2002-2003, stage Week17
# processing primeira-liga, season 2002-2003, stage Week18
# processing primeira-liga, season 2002-2003, stage Week19
# processing primeira-liga, season 2002-2003, stage Week20
# processing primeira-liga, season 2002-2003, stage Week21
# processing primeira-liga, season 2002-2003, stage Week22
# processing primeira-liga, season 2002-2003, stage Week23
# processing primeira-liga, season 2002-2003, stage Week24
# processing primeira-liga, season 2002-2003, stage Week25
# processing primeira-liga, season 2002-2003, stage Week26
# processing primeira-liga, season 2002-2003, stage Week27
# processing primeira-liga, season 2002-2003, stage Week28
# processing primeira-liga, season 2002-2003, stage Week29
# processing primeira-liga, season 2002-2003, stage Week30
# processing primeira-liga, season 2002-2003, stage Week31
# processing primeira-liga, season 2002-2003, stage Week32
# processing primeira-liga, season 2002-2003, stage Week33
# processing primeira-liga, season 2002-2003, stage Week34
# --------------------------------
# processing season 2001-2002
# --------------------------------
# processing primeira-liga, season 2001-2002, stage Week01
# processing primeira-liga, season 2001-2002, stage Week02
# processing primeira-liga, season 2001-2002, stage Week03
# processing primeira-liga, season 2001-2002, stage Week04
# processing primeira-liga, season 2001-2002, stage Week05
# processing primeira-liga, season 2001-2002, stage Week06
# processing primeira-liga, season 2001-2002, stage Week07
# processing primeira-liga, season 2001-2002, stage Week08
# processing primeira-liga, season 2001-2002, stage Week09
# processing primeira-liga, season 2001-2002, stage Week10
# processing primeira-liga, season 2001-2002, stage Week11
# processing primeira-liga, season 2001-2002, stage Week12
# processing primeira-liga, season 2001-2002, stage Week13
# processing primeira-liga, season 2001-2002, stage Week14
# processing primeira-liga, season 2001-2002, stage Week15
# processing primeira-liga, season 2001-2002, stage Week16
# processing primeira-liga, season 2001-2002, stage Week17
# processing primeira-liga, season 2001-2002, stage Week18
# processing primeira-liga, season 2001-2002, stage Week19
# processing primeira-liga, season 2001-2002, stage Week20
# processing primeira-liga, season 2001-2002, stage Week21
# processing primeira-liga, season 2001-2002, stage Week22
# processing primeira-liga, season 2001-2002, stage Week23
# processing primeira-liga, season 2001-2002, stage Week24
# processing primeira-liga, season 2001-2002, stage Week25
# processing primeira-liga, season 2001-2002, stage Week26
# processing primeira-liga, season 2001-2002, stage Week27
# processing primeira-liga, season 2001-2002, stage Week28
# processing primeira-liga, season 2001-2002, stage Week29
# processing primeira-liga, season 2001-2002, stage Week30
# processing primeira-liga, season 2001-2002, stage Week31
# processing primeira-liga, season 2001-2002, stage Week32
# processing primeira-liga, season 2001-2002, stage Week33
# processing primeira-liga, season 2001-2002, stage Week34
# --------------------------------
# processing season 2000-2001
# --------------------------------
# processing primeira-liga, season 2000-2001, stage Week01
# processing primeira-liga, season 2000-2001, stage Week02
# processing primeira-liga, season 2000-2001, stage Week03
# processing primeira-liga, season 2000-2001, stage Week04
# processing primeira-liga, season 2000-2001, stage Week05
# processing primeira-liga, season 2000-2001, stage Week06
# processing primeira-liga, season 2000-2001, stage Week07
# processing primeira-liga, season 2000-2001, stage Week08
# processing primeira-liga, season 2000-2001, stage Week09
# processing primeira-liga, season 2000-2001, stage Week10
# processing primeira-liga, season 2000-2001, stage Week11
# processing primeira-liga, season 2000-2001, stage Week12
# processing primeira-liga, season 2000-2001, stage Week13
# processing primeira-liga, season 2000-2001, stage Week14
# processing primeira-liga, season 2000-2001, stage Week15
# processing primeira-liga, season 2000-2001, stage Week16
# processing primeira-liga, season 2000-2001, stage Week17
# processing primeira-liga, season 2000-2001, stage Week18
# processing primeira-liga, season 2000-2001, stage Week19
# processing primeira-liga, season 2000-2001, stage Week20
# processing primeira-liga, season 2000-2001, stage Week21
# processing primeira-liga, season 2000-2001, stage Week22
# processing primeira-liga, season 2000-2001, stage Week23
# processing primeira-liga, season 2000-2001, stage Week24
# processing primeira-liga, season 2000-2001, stage Week25
# processing primeira-liga, season 2000-2001, stage Week26
# processing primeira-liga, season 2000-2001, stage Week27
# processing primeira-liga, season 2000-2001, stage Week28
# processing primeira-liga, season 2000-2001, stage Week29
# processing primeira-liga, season 2000-2001, stage Week30
# processing primeira-liga, season 2000-2001, stage Week31
# processing primeira-liga, season 2000-2001, stage Week32
# processing primeira-liga, season 2000-2001, stage Week33
# processing primeira-liga, season 2000-2001, stage Week34
# --------------------------------
# processing season 1999-2000
# --------------------------------
# processing primeira-liga, season 1999-2000, stage Week01
# processing primeira-liga, season 1999-2000, stage Week02
# processing primeira-liga, season 1999-2000, stage Week03
# processing primeira-liga, season 1999-2000, stage Week04
# processing primeira-liga, season 1999-2000, stage Week05
# processing primeira-liga, season 1999-2000, stage Week06
# processing primeira-liga, season 1999-2000, stage Week07
# processing primeira-liga, season 1999-2000, stage Week08
# processing primeira-liga, season 1999-2000, stage Week09
# processing primeira-liga, season 1999-2000, stage Week10
# processing primeira-liga, season 1999-2000, stage Week11
# processing primeira-liga, season 1999-2000, stage Week12
# processing primeira-liga, season 1999-2000, stage Week13
# processing primeira-liga, season 1999-2000, stage Week14
# processing primeira-liga, season 1999-2000, stage Week15
# processing primeira-liga, season 1999-2000, stage Week16
# processing primeira-liga, season 1999-2000, stage Week17
# processing primeira-liga, season 1999-2000, stage Week18
# processing primeira-liga, season 1999-2000, stage Week19
# processing primeira-liga, season 1999-2000, stage Week20
# processing primeira-liga, season 1999-2000, stage Week21
# processing primeira-liga, season 1999-2000, stage Week22
# processing primeira-liga, season 1999-2000, stage Week23
# processing primeira-liga, season 1999-2000, stage Week24
# processing primeira-liga, season 1999-2000, stage Week25
# processing primeira-liga, season 1999-2000, stage Week26
# processing primeira-liga, season 1999-2000, stage Week27
# processing primeira-liga, season 1999-2000, stage Week28
# processing primeira-liga, season 1999-2000, stage Week29
# processing primeira-liga, season 1999-2000, stage Week30
# processing primeira-liga, season 1999-2000, stage Week31
# processing primeira-liga, season 1999-2000, stage Week32
# processing primeira-liga, season 1999-2000, stage Week33
# processing primeira-liga, season 1999-2000, stage Week34
# --------------------------------
# processing season 1998-1999
# --------------------------------
# processing primeira-liga, season 1998-1999, stage Week01
# processing primeira-liga, season 1998-1999, stage Week02
# processing primeira-liga, season 1998-1999, stage Week03
# processing primeira-liga, season 1998-1999, stage Week04
# processing primeira-liga, season 1998-1999, stage Week05
# processing primeira-liga, season 1998-1999, stage Week06
# processing primeira-liga, season 1998-1999, stage Week07
# processing primeira-liga, season 1998-1999, stage Week08
# processing primeira-liga, season 1998-1999, stage Week09
# processing primeira-liga, season 1998-1999, stage Week10
# processing primeira-liga, season 1998-1999, stage Week11
# processing primeira-liga, season 1998-1999, stage Week12
# processing primeira-liga, season 1998-1999, stage Week13
# processing primeira-liga, season 1998-1999, stage Week14
# processing primeira-liga, season 1998-1999, stage Week15
# processing primeira-liga, season 1998-1999, stage Week16
# processing primeira-liga, season 1998-1999, stage Week17
# processing primeira-liga, season 1998-1999, stage Week18
# processing primeira-liga, season 1998-1999, stage Week19
# processing primeira-liga, season 1998-1999, stage Week20
# processing primeira-liga, season 1998-1999, stage Week21
# processing primeira-liga, season 1998-1999, stage Week22
# processing primeira-liga, season 1998-1999, stage Week23
# processing primeira-liga, season 1998-1999, stage Week24
# processing primeira-liga, season 1998-1999, stage Week25
# processing primeira-liga, season 1998-1999, stage Week26
# processing primeira-liga, season 1998-1999, stage Week27
# processing primeira-liga, season 1998-1999, stage Week28
# processing primeira-liga, season 1998-1999, stage Week29
# processing primeira-liga, season 1998-1999, stage Week30
# processing primeira-liga, season 1998-1999, stage Week31
# processing primeira-liga, season 1998-1999, stage Week32
# processing primeira-liga, season 1998-1999, stage Week33
# processing primeira-liga, season 1998-1999, stage Week34
# --------------------------------
# processing season 1997-1998
# --------------------------------
# processing primeira-liga, season 1997-1998, stage Week01
# processing primeira-liga, season 1997-1998, stage Week02
# processing primeira-liga, season 1997-1998, stage Week03
# processing primeira-liga, season 1997-1998, stage Week04
# processing primeira-liga, season 1997-1998, stage Week05
# processing primeira-liga, season 1997-1998, stage Week06
# processing primeira-liga, season 1997-1998, stage Week07
# processing primeira-liga, season 1997-1998, stage Week08
# processing primeira-liga, season 1997-1998, stage Week09
# processing primeira-liga, season 1997-1998, stage Week10
# processing primeira-liga, season 1997-1998, stage Week11
# processing primeira-liga, season 1997-1998, stage Week12
# processing primeira-liga, season 1997-1998, stage Week13
# processing primeira-liga, season 1997-1998, stage Week14
# processing primeira-liga, season 1997-1998, stage Week15
# processing primeira-liga, season 1997-1998, stage Week16
# processing primeira-liga, season 1997-1998, stage Week17
# processing primeira-liga, season 1997-1998, stage Week18
# processing primeira-liga, season 1997-1998, stage Week19
# processing primeira-liga, season 1997-1998, stage Week20
# processing primeira-liga, season 1997-1998, stage Week21
# processing primeira-liga, season 1997-1998, stage Week22
# processing primeira-liga, season 1997-1998, stage Week23
# processing primeira-liga, season 1997-1998, stage Week24
# processing primeira-liga, season 1997-1998, stage Week25
# processing primeira-liga, season 1997-1998, stage Week26
# processing primeira-liga, season 1997-1998, stage Week27
# processing primeira-liga, season 1997-1998, stage Week28
# processing primeira-liga, season 1997-1998, stage Week29
# processing primeira-liga, season 1997-1998, stage Week30
# processing primeira-liga, season 1997-1998, stage Week31
# processing primeira-liga, season 1997-1998, stage Week32
# processing primeira-liga, season 1997-1998, stage Week33
# processing primeira-liga, season 1997-1998, stage Week34
# --------------------------------
# processing season 1996-1997
# --------------------------------
# processing primeira-liga, season 1996-1997, stage Week01
# processing primeira-liga, season 1996-1997, stage Week02
# processing primeira-liga, season 1996-1997, stage Week03
# processing primeira-liga, season 1996-1997, stage Week04
# processing primeira-liga, season 1996-1997, stage Week05
# processing primeira-liga, season 1996-1997, stage Week06
# processing primeira-liga, season 1996-1997, stage Week07
# processing primeira-liga, season 1996-1997, stage Week08
# processing primeira-liga, season 1996-1997, stage Week09
# processing primeira-liga, season 1996-1997, stage Week10
# processing primeira-liga, season 1996-1997, stage Week11
# processing primeira-liga, season 1996-1997, stage Week12
# processing primeira-liga, season 1996-1997, stage Week13
# processing primeira-liga, season 1996-1997, stage Week14
# processing primeira-liga, season 1996-1997, stage Week15
# processing primeira-liga, season 1996-1997, stage Week16
# processing primeira-liga, season 1996-1997, stage Week17
# processing primeira-liga, season 1996-1997, stage Week18
# processing primeira-liga, season 1996-1997, stage Week19
# processing primeira-liga, season 1996-1997, stage Week20
# processing primeira-liga, season 1996-1997, stage Week21
# processing primeira-liga, season 1996-1997, stage Week22
# processing primeira-liga, season 1996-1997, stage Week23
# processing primeira-liga, season 1996-1997, stage Week24
# processing primeira-liga, season 1996-1997, stage Week25
# processing primeira-liga, season 1996-1997, stage Week26
# processing primeira-liga, season 1996-1997, stage Week27
# processing primeira-liga, season 1996-1997, stage Week28
# processing primeira-liga, season 1996-1997, stage Week29
# processing primeira-liga, season 1996-1997, stage Week30
# processing primeira-liga, season 1996-1997, stage Week31
# processing primeira-liga, season 1996-1997, stage Week32
# processing primeira-liga, season 1996-1997, stage Week33
# processing primeira-liga, season 1996-1997, stage Week34
# --------------------------------
# processing season 1995-1996
# --------------------------------
# processing primeira-liga, season 1995-1996, stage Week01
# processing primeira-liga, season 1995-1996, stage Week02
# processing primeira-liga, season 1995-1996, stage Week03
# processing primeira-liga, season 1995-1996, stage Week04
# processing primeira-liga, season 1995-1996, stage Week05
# processing primeira-liga, season 1995-1996, stage Week06
# processing primeira-liga, season 1995-1996, stage Week07
# processing primeira-liga, season 1995-1996, stage Week08
# processing primeira-liga, season 1995-1996, stage Week09
# processing primeira-liga, season 1995-1996, stage Week10
# processing primeira-liga, season 1995-1996, stage Week11
# processing primeira-liga, season 1995-1996, stage Week12
# processing primeira-liga, season 1995-1996, stage Week13
# processing primeira-liga, season 1995-1996, stage Week14
# processing primeira-liga, season 1995-1996, stage Week15
# processing primeira-liga, season 1995-1996, stage Week16
# processing primeira-liga, season 1995-1996, stage Week17
# processing primeira-liga, season 1995-1996, stage Week18
# processing primeira-liga, season 1995-1996, stage Week19
# processing primeira-liga, season 1995-1996, stage Week20
# processing primeira-liga, season 1995-1996, stage Week21
# processing primeira-liga, season 1995-1996, stage Week22
# processing primeira-liga, season 1995-1996, stage Week23
# processing primeira-liga, season 1995-1996, stage Week24
# processing primeira-liga, season 1995-1996, stage Week25
# processing primeira-liga, season 1995-1996, stage Week26
# processing primeira-liga, season 1995-1996, stage Week27
# processing primeira-liga, season 1995-1996, stage Week28
# processing primeira-liga, season 1995-1996, stage Week29
# processing primeira-liga, season 1995-1996, stage Week30
# processing primeira-liga, season 1995-1996, stage Week31
# processing primeira-liga, season 1995-1996, stage Week32
# processing primeira-liga, season 1995-1996, stage Week33
# processing primeira-liga, season 1995-1996, stage Week34
# --------------------------------
# processing season 1994-1995
# --------------------------------
# processing primeira-liga, season 1994-1995, stage Week01
# processing primeira-liga, season 1994-1995, stage Week02
# processing primeira-liga, season 1994-1995, stage Week03
# processing primeira-liga, season 1994-1995, stage Week04
# processing primeira-liga, season 1994-1995, stage Week05
# processing primeira-liga, season 1994-1995, stage Week06
# processing primeira-liga, season 1994-1995, stage Week07
# processing primeira-liga, season 1994-1995, stage Week08
# processing primeira-liga, season 1994-1995, stage Week09
# processing primeira-liga, season 1994-1995, stage Week10
# processing primeira-liga, season 1994-1995, stage Week11
# processing primeira-liga, season 1994-1995, stage Week12
# processing primeira-liga, season 1994-1995, stage Week13
# processing primeira-liga, season 1994-1995, stage Week14
# processing primeira-liga, season 1994-1995, stage Week15
# processing primeira-liga, season 1994-1995, stage Week16
# processing primeira-liga, season 1994-1995, stage Week17
# processing primeira-liga, season 1994-1995, stage Week18
# processing primeira-liga, season 1994-1995, stage Week19
# processing primeira-liga, season 1994-1995, stage Week20
# processing primeira-liga, season 1994-1995, stage Week21
# processing primeira-liga, season 1994-1995, stage Week22
# processing primeira-liga, season 1994-1995, stage Week23
# processing primeira-liga, season 1994-1995, stage Week24
# processing primeira-liga, season 1994-1995, stage Week25
# processing primeira-liga, season 1994-1995, stage Week26
# processing primeira-liga, season 1994-1995, stage Week27
# processing primeira-liga, season 1994-1995, stage Week28
# processing primeira-liga, season 1994-1995, stage Week29
# processing primeira-liga, season 1994-1995, stage Week30
# processing primeira-liga, season 1994-1995, stage Week31
# processing primeira-liga, season 1994-1995, stage Week32
# processing primeira-liga, season 1994-1995, stage Week33
# processing primeira-liga, season 1994-1995, stage Week34
# --------------------------------
# processing season 1993-1994
# --------------------------------
# processing primeira-liga, season 1993-1994, stage Week01
# processing primeira-liga, season 1993-1994, stage Week02
# processing primeira-liga, season 1993-1994, stage Week03
# processing primeira-liga, season 1993-1994, stage Week04
# processing primeira-liga, season 1993-1994, stage Week05
# processing primeira-liga, season 1993-1994, stage Week06
# processing primeira-liga, season 1993-1994, stage Week07
# processing primeira-liga, season 1993-1994, stage Week08
# processing primeira-liga, season 1993-1994, stage Week09
# processing primeira-liga, season 1993-1994, stage Week10
# processing primeira-liga, season 1993-1994, stage Week11
# processing primeira-liga, season 1993-1994, stage Week12
# ...
# processing taca, season 2006-2007, stage Round of 16
# processing taca, season 2006-2007, stage Quarter-finals
# processing taca, season 2006-2007, stage Semi-finals
# processing taca, season 2006-2007, stage Final
# --------------------------------
# processing season 2005-2006
# --------------------------------
# processing taca, season 2005-2006, stage 4. Round
# processing taca, season 2005-2006, stage 5. Round
# processing taca, season 2005-2006, stage Round of 16
# processing taca, season 2005-2006, stage Quarter-finals
# processing taca, season 2005-2006, stage Semi-finals
# processing taca, season 2005-2006, stage Final
# --------------------------------
# processing season 2004-2005
# --------------------------------
# processing taca, season 2004-2005, stage 4. Round
# processing taca, season 2004-2005, stage 5. Round
# processing taca, season 2004-2005, stage Round of 16
# processing taca, season 2004-2005, stage Quarter-finals
# processing taca, season 2004-2005, stage Semi-finals
# processing taca, season 2004-2005, stage Final
# --------------------------------
# processing season 2003-2004
# --------------------------------
# processing taca, season 2003-2004, stage 4. Round
# processing taca, season 2003-2004, stage 5. Round
# processing taca, season 2003-2004, stage Round of 16
# processing taca, season 2003-2004, stage Quarter-finals
# processing taca, season 2003-2004, stage Semi-finals
# processing taca, season 2003-2004, stage Final
# --------------------------------
# processing season 2002-2003
# --------------------------------
# processing taca, season 2002-2003, stage 4. Round
# processing taca, season 2002-2003, stage 5. Round
# processing taca, season 2002-2003, stage Round of 16
# processing taca, season 2002-2003, stage Quarter-finals
# processing taca, season 2002-2003, stage Semi-finals
# processing taca, season 2002-2003, stage Final
# --------------------------------
# processing season 2001-2002
# --------------------------------
# processing taca, season 2001-2002, stage 4. Round
# processing taca, season 2001-2002, stage 5. Round
# processing taca, season 2001-2002, stage Round of 16
# processing taca, season 2001-2002, stage Quarter-finals
# processing taca, season 2001-2002, stage Semi-finals
# processing taca, season 2001-2002, stage Final
# --------------------------------
# processing season 2000-2001
# --------------------------------
# processing taca, season 2000-2001, stage 4. Round
# processing taca, season 2000-2001, stage 5. Round
# processing taca, season 2000-2001, stage Round of 16
# processing taca, season 2000-2001, stage Quarter-finals
# processing taca, season 2000-2001, stage Semi-finals
# processing taca, season 2000-2001, stage Final
# --------------------------------
# processing season 1999-2000
# --------------------------------
# processing taca, season 1999-2000, stage 4. Round
# processing taca, season 1999-2000, stage 5. Round
# processing taca, season 1999-2000, stage Round of 16
# processing taca, season 1999-2000, stage Quarter-finals
# processing taca, season 1999-2000, stage Semi-finals
# processing taca, season 1999-2000, stage Final
# --------------------------------
# processing season 1998-1999
# --------------------------------
# processing taca, season 1998-1999, stage Final
# --------------------------------
# processing season 1997-1998
# --------------------------------
# processing taca, season 1997-1998, stage Final
# --------------------------------
# processing season 1996-1997
# --------------------------------
# processing taca, season 1996-1997, stage Final
# --------------------------------
# processing season 1995-1996
# --------------------------------
# processing taca, season 1995-1996, stage Final
# --------------------------------
# processing season 1994-1995
# --------------------------------
# processing taca, season 1994-1995, stage Final
# --------------------------------
# processing season 1993-1994
# --------------------------------
# processing taca, season 1993-1994, stage Final
# --------------------------------
# processing season 1992-1993
# --------------------------------
# processing taca, season 1992-1993, stage Final
# --------------------------------
# processing season 1991-1992
# --------------------------------
# processing taca, season 1991-1992, stage Final
# --------------------------------
# processing season 1990-1991
# --------------------------------
# processing taca, season 1990-1991, stage Final
# --------------------------------
# processing season 1989-1990
# --------------------------------
# processing taca, season 1989-1990, stage Final
# --------------------------------
# processing season 1988-1989
# --------------------------------
# processing taca, season 1988-1989, stage Final
# --------------------------------
# processing season 1987-1988
# --------------------------------
# processing taca, season 1987-1988, stage Final
# --------------------------------
# processing season 1986-1987
# --------------------------------
# processing taca, season 1986-1987, stage Final
# --------------------------------
# processing season 1985-1986
# --------------------------------
# processing taca, season 1985-1986, stage Final
# --------------------------------
# processing season 1984-1985
# --------------------------------
# processing taca, season 1984-1985, stage Final
# --------------------------------
# processing season 1983-1984
# --------------------------------
# processing taca, season 1983-1984, stage Final
# --------------------------------
# processing season 1982-1983
# --------------------------------
# processing taca, season 1982-1983, stage Final
# --------------------------------
# processing season 1981-1982
# --------------------------------
# processing taca, season 1981-1982, stage Final
# --------------------------------
# processing season 1980-1981
# --------------------------------
# processing taca, season 1980-1981, stage Final
# --------------------------------
# processing season 1979-1980
# --------------------------------
# processing taca, season 1979-1980, stage Final
# ignoring season 1978-1979
# ignoring season 1977-1978
# ignoring season 1976-1977
# ignoring season 1975-1976
# ignoring season 1974-1975
# ignoring season 1973-1974
# ignoring season 1972-1973
# ignoring season 1971-1972
# ignoring season 1970-1971
# ignoring season 1969-1970
# ignoring season 1968-1969
# ignoring season 1967-1968
# ignoring season 1966-1967
# ignoring season 1965-1966
# ignoring season 1964-1965
# ignoring season 1963-1964
# ignoring season 1962-1963
# ignoring season 1961-1962
# ignoring season 1960-1961
# ignoring season 1959-1960
# ignoring season 1958-1959
# ignoring season 1957-1958
# ignoring season 1956-1957
# ignoring season 1955-1956
# ignoring season 1954-1955
# ignoring season 1953-1954
# ignoring season 1952-1953
# ignoring season 1951-1952
# ignoring season 1950-1951
# ignoring season 1948-1949
# ignoring season 1947-1948
# ignoring season 1945-1946
# ignoring season 1944-1945
# ignoring season 1943-1944
# ignoring season 1942-1943
# ignoring season 1941-1942
# ignoring season 1940-1941
# ignoring season 1939-1940
# ignoring season 1938-1939
# **********************************************
# processing competition taca-da-liga
# **********************************************
# --------------------------------
# processing season 2017-2018
# --------------------------------
# processing taca-da-liga, season 2017-2018, stage 1. Round
# processing taca-da-liga, season 2017-2018, stage 2. Round
# --------------------------------
# processing season 2016-2017
# --------------------------------
# processing taca-da-liga, season 2016-2017, stage 1. Round
# processing taca-da-liga, season 2016-2017, stage 2. Round
# processing taca-da-liga, season 2016-2017, stage Group A
# processing taca-da-liga, season 2016-2017, stage Group B
# processing taca-da-liga, season 2016-2017, stage Group C
# processing taca-da-liga, season 2016-2017, stage Group D
# processing taca-da-liga, season 2016-2017, stage Semi-finals
# processing taca-da-liga, season 2016-2017, stage Final
# --------------------------------
# processing season 2015-2016
# --------------------------------
# processing taca-da-liga, season 2015-2016, stage 1. Round
# processing taca-da-liga, season 2015-2016, stage 2. Round
# processing taca-da-liga, season 2015-2016, stage Group A
# processing taca-da-liga, season 2015-2016, stage Group B
# processing taca-da-liga, season 2015-2016, stage Group C
# processing taca-da-liga, season 2015-2016, stage Group D
# processing taca-da-liga, season 2015-2016, stage Semi-finals
# processing taca-da-liga, season 2015-2016, stage Final
# --------------------------------
# processing season 2014-2015
# --------------------------------
# processing taca-da-liga, season 2014-2015, stage Group A
# processing taca-da-liga, season 2014-2015, stage Group B
# processing taca-da-liga, season 2014-2015, stage Group C
# processing taca-da-liga, season 2014-2015, stage Group D
# processing taca-da-liga, season 2014-2015, stage 2. Round
# processing taca-da-liga, season 2014-2015, stage 3. Round Group A
# processing taca-da-liga, season 2014-2015, stage 3rd Round Group B
# processing taca-da-liga, season 2014-2015, stage 3rd Round Group C
# processing taca-da-liga, season 2014-2015, stage 3rd Round Group D
# processing taca-da-liga, season 2014-2015, stage Semi-finals
# processing taca-da-liga, season 2014-2015, stage Final
# --------------------------------
# processing season 2013-2014
# --------------------------------
# processing taca-da-liga, season 2013-2014, stage Group A
# processing taca-da-liga, season 2013-2014, stage Group B
# processing taca-da-liga, season 2013-2014, stage Group C
# processing taca-da-liga, season 2013-2014, stage Group D
# processing taca-da-liga, season 2013-2014, stage 2. Round
# processing taca-da-liga, season 2013-2014, stage 3. Round Group A
# processing taca-da-liga, season 2013-2014, stage 3rd Round Group B
# processing taca-da-liga, season 2013-2014, stage 3rd Round Group C
# processing taca-da-liga, season 2013-2014, stage 3rd Round Group D
# processing taca-da-liga, season 2013-2014, stage Semi-finals
# processing taca-da-liga, season 2013-2014, stage Final
# --------------------------------
# processing season 2012-2013
# --------------------------------
# processing taca-da-liga, season 2012-2013, stage Group A
# processing taca-da-liga, season 2012-2013, stage Group B
# processing taca-da-liga, season 2012-2013, stage Group C
# processing taca-da-liga, season 2012-2013, stage Group D
# processing taca-da-liga, season 2012-2013, stage 2. Round
# processing taca-da-liga, season 2012-2013, stage 3. Round Group A
# processing taca-da-liga, season 2012-2013, stage 3rd Round Group B
# processing taca-da-liga, season 2012-2013, stage 3rd Round Group C
# processing taca-da-liga, season 2012-2013, stage 3rd Round Group D
# processing taca-da-liga, season 2012-2013, stage Semi-finals
# processing taca-da-liga, season 2012-2013, stage Final
# --------------------------------
# processing season 2011-2012
# --------------------------------
# processing taca-da-liga, season 2011-2012, stage Group A
# processing taca-da-liga, season 2011-2012, stage Group B
# processing taca-da-liga, season 2011-2012, stage Group C
# processing taca-da-liga, season 2011-2012, stage Group D
# processing taca-da-liga, season 2011-2012, stage 2. Round
# processing taca-da-liga, season 2011-2012, stage 3. Round Group A
# processing taca-da-liga, season 2011-2012, stage 3rd Round Group B
# processing taca-da-liga, season 2011-2012, stage 3rd Round Group C
# processing taca-da-liga, season 2011-2012, stage 3rd Round Group D
# processing taca-da-liga, season 2011-2012, stage Semi-finals
# processing taca-da-liga, season 2011-2012, stage Final
# --------------------------------
# processing season 2010-2011
# --------------------------------
# processing taca-da-liga, season 2010-2011, stage Group A
# processing taca-da-liga, season 2010-2011, stage Group B
# processing taca-da-liga, season 2010-2011, stage Group C
# processing taca-da-liga, season 2010-2011, stage Group D
# processing taca-da-liga, season 2010-2011, stage 2. Round
# processing taca-da-liga, season 2010-2011, stage 3. Round Group A
# processing taca-da-liga, season 2010-2011, stage 3rd Round Group B
# processing taca-da-liga, season 2010-2011, stage 3rd Round Group C
# processing taca-da-liga, season 2010-2011, stage 3rd Round Group D
# processing taca-da-liga, season 2010-2011, stage Semi-finals
# processing taca-da-liga, season 2010-2011, stage Final
# --------------------------------
# processing season 2009-2010
# --------------------------------
# processing taca-da-liga, season 2009-2010, stage Qualifier
# processing taca-da-liga, season 2009-2010, stage Group A
# processing taca-da-liga, season 2009-2010, stage Group B
# processing taca-da-liga, season 2009-2010, stage Group C
# processing taca-da-liga, season 2009-2010, stage Group D
# processing taca-da-liga, season 2009-2010, stage Group E
# processing taca-da-liga, season 2009-2010, stage Group F
# processing taca-da-liga, season 2009-2010, stage 2nd Round Group A
# processing taca-da-liga, season 2009-2010, stage 2. Round Group B
# processing taca-da-liga, season 2009-2010, stage 2. Round Group C
# processing taca-da-liga, season 2009-2010, stage Semi-finals
# processing taca-da-liga, season 2009-2010, stage Final
# --------------------------------
# processing season 2008-2009
# --------------------------------
# processing taca-da-liga, season 2008-2009, stage Qualifier
# processing taca-da-liga, season 2008-2009, stage Group A
# processing taca-da-liga, season 2008-2009, stage Group B
# processing taca-da-liga, season 2008-2009, stage Group C
# processing taca-da-liga, season 2008-2009, stage Group D
# processing taca-da-liga, season 2008-2009, stage Group E
# processing taca-da-liga, season 2008-2009, stage Group F
# processing taca-da-liga, season 2008-2009, stage 2nd Round Group A
# processing taca-da-liga, season 2008-2009, stage 2. Round Group B
# processing taca-da-liga, season 2008-2009, stage 2. Round Group C
# processing taca-da-liga, season 2008-2009, stage Semi-finals
# processing taca-da-liga, season 2008-2009, stage Final
# --------------------------------
# processing season 2007-2008
# --------------------------------
# processing taca-da-liga, season 2007-2008, stage 1. Round
# processing taca-da-liga, season 2007-2008, stage 2. Round
# processing taca-da-liga, season 2007-2008, stage 3. Round
# processing taca-da-liga, season 2007-2008, stage 4. Round
# processing taca-da-liga, season 2007-2008, stage 5. Round
# processing taca-da-liga, season 2007-2008, stage Final
# **********************************************
# processing competition supertaca
# **********************************************
# --------------------------------
# processing season 2017
# --------------------------------
# processing supertaca, season 2017, stage Final
# --------------------------------
# processing season 2016
# --------------------------------
# processing supertaca, season 2016, stage Final
# --------------------------------
# processing season 2015
# --------------------------------
# processing supertaca, season 2015, stage Supercup
# --------------------------------
# processing season 2014
# --------------------------------
# processing supertaca, season 2014, stage Final
# --------------------------------
# processing season 2013
# --------------------------------
# processing supertaca, season 2013, stage Final
# --------------------------------
# processing season 2012
# --------------------------------
# processing supertaca, season 2012, stage Final
# --------------------------------
# processing season 2011
# --------------------------------
# processing supertaca, season 2011, stage Final
# --------------------------------
# processing season 2010
# --------------------------------
# processing supertaca, season 2010, stage Final
# --------------------------------
# processing season 2009
# --------------------------------
# processing supertaca, season 2009, stage Final
# --------------------------------
# processing season 2008
# --------------------------------
# processing supertaca, season 2008, stage Final
# --------------------------------
# processing season 2007
# --------------------------------
# processing supertaca, season 2007, stage Final
# --------------------------------
# processing season 2006
# --------------------------------
# processing supertaca, season 2006, stage Final
# Process finished
