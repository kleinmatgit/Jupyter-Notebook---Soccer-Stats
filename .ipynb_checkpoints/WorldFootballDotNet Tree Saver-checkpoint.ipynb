# %% [markdown]
# # Introduction

# %% [markdown]
# The goal of this notebook is to analyse worldfootball.net urls and save down results page into tree structure. This will be used later on to get results and save it under a more readable format (csv).
#
# The trees will be saved on the drive under a specific folder hierarchy:
# zone -> competition -> season -> stage.html
#
# for instance:
# france -> ligue1 -> 2016-2017 -> Week01.html
#
# Stage name is then the tree file name.

# %% [markdown]
# # Import

# %%
import lxml.html as lh
import lxml.etree as et
from selenium import webdriver
import time
import pickle
import traceback
import logging
import os.path
import configparser
import os
import re
import datetime

# %% [markdown]
# # Params

# %%
root_path = 'L:/Dev/Sandbox/Apps Development/SoccerWebApp/PySoccer/WorldFootballDotNet/'
conf_path = os.path.join(root_path, '_conf','worldfootball.ini')
log_path = os.path.join(root_path, '_logs')
website_url = 'https://www.worldfootball.net'

# %% [markdown]
# # Logging

# %%
logger = logging.getLogger('myapp')
timestamp = datetime.datetime.now().strftime('%H%M%S')
hdlr = logging.FileHandler(os.path.join(log_path,'worldfootballnet_TreeSaver_' + timestamp + '.log'))
formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
hdlr.setFormatter(formatter)
logger.addHandler(hdlr) 
logger.setLevel(logging.DEBUG)

# %%
def logWrapper(message, level="info", print_console=True):
    if(print_console):
        print(message)
    if(level=="info"):
        logger.info(message)
    elif(level=="warning"):
        logger.warning(message)
    elif(level=="debug"):
        logger.debug(message)
    elif(level=="error"):
        logger.error(message)

# %%
#logger.error("test error")
#logger.warning("this is a warning")
#logger.info("this is just info")
#logger.debug("this is debug")
#logWrapper('hello world')
#logWrapper('message')

# %% [markdown]
# # Conf

# %%
class ConfHandler():

    dicSections = {}
    
    def __init__(self,file_full_path):

        if not os.path.exists(file_full_path):
            raise Exception('path not correct: {0}'.format(file_full_path))
        
        config = configparser.ConfigParser()
        config.read(file_full_path)
        
        for s in config.sections():
            dicParams = {}
            for p in config[s]:
                dicParams[p] = config[s][p]
            self.dicSections[s] = dicParams

    def get(self,section,param, is_param_list = False):
        if(is_param_list):
            return self.dicSections[section][param].replace(' ','').split(',')
        return self.dicSections[section][param]
    
    def get_section(self,section):
        return self.dicSections[section]
    
    def get_sections(self):
        return sorted(list(self.dicSections.keys()))

# %%
# test conf
#conf = ConfHandler(conf_path)
#print(conf.get('france','ligue1'))
#dic = conf.get_section('france')
#print(dic)
#sections = conf.get_sections()
#print(sections)
#print(conf.get('cup', 'club_cup_list', True))

# %% [markdown]
# # Functions

# %% [markdown]
# ## [selenium_url_to_tree] download url final output as a tree

# %%
# get url html as elementtree using selenium.webdriver
def selenium_url_to_tree(driver, url):
    driver.get(url)
    time.sleep(2)
    htmlSource = driver.page_source
    tree = lh.fromstring(htmlSource)
    return tree

# HOW IT WORKS....
# open driver: that will open firefox window
#driver = webdriver.Firefox()

# construct the trees only once
#results_tree = selenium_url_to_tree(driver,week_url)

# close firefox window once done
#driver.quit()

# %%
# return html page as a tree.
# the tree object will be cached to drive so next call won't require web call
def get_tree_from_url(driver, filename, url):
    
    # file doesn't exist, we will have to do a web call
    if(not os.path.isfile(filename)):
        
        # create folder if not done already
        if not os.path.exists(os.path.dirname(filename)):
            try:
                os.makedirs(os.path.dirname(filename))
            except OSError as exc: # Guard against race condition
                if exc.errno != errno.EEXIST:
                    raise
        
        # load up url in web browser
        tree = selenium_url_to_tree(driver,url)
        
        # save it down to the drive
        tree.getroottree().write(filename)
        
        if(not os.path.isfile(filename)):
            raise
        
    # return the loaded tree
    return lh.fromstring(open(filename, 'r').read())

# %%
def get_result_url_from_tree(tree):
    return tree.find('.//div[@class="navibox2"]//div[@class="data"]/ul[2]/li/a').attrib['href']

# %%
# construct dictionary of {season: url}
def get_seasons_dic_from_tree(tree):
    options = tree.findall('.//select[@name="saison"]/option')
    dic = {}
    for option in options:
        season = option.text_content().replace('/','-')
        dic[season] = option.attrib['value']
    return dic

# %%
# construct dictionary of {stage: url}
def get_stages_dic_from_tree(tree):
    
    dic = {}
    
    is_cup = False
    
    # assume we are looking at a 'league' tree
    options = tree.findall('.//select[@name="runde"]/option')
    
    if len(options) == 0:
        # now trying to see if we are looking at a 'cup' tree
        options = tree.findall('.//select[@name="phase"]/option')
        
        if len(options) == 0:
            raise
        else:
            is_cup = True
    
    for option in options:
        stage = option.text_content()
        if(is_cup):
            dic[stage] = option.attrib['value']
        else:
            stage = stage[:stage.find('.')]
            dic['Week' + str('%02d' % int(stage))] = option.attrib['value']
    return dic

# %%
# use regex to find season in an url (ie: 2016-2017)
def match_season(url):
    matchObj = re.match(r'.*([1-3][0-9]{3}-[1-3][0-9]{3}).*', url)
    if not matchObj:
        # sometime we get only year instead of season
        matchObj = re.match(r'.*([1-3][0-9]{3}).*', url)
        if not matchObj:
            raise
    return matchObj.group(1)

# %%
# use regex to find stage in an url (ie: '1' or '38' or 'final')
def match_stage_in_url(url):
    
    # league url
    matchObj = re.match(r'.*[1-3][0-9]{3}-[1-3][0-9]{3}-spieltag/(\b\d{1,2}\b)/', url)
    if matchObj:
        return 'Week' + str('%02d' % int(matchObj.group(1)))
    
    # qualification url: https://www.worldfootball.net/schedule/wm-quali-suedamerika-2010-spieltag/18/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-spieltag/(\b\d{1,2}\b)/', url)
    if matchObj:
        return 'Week' + str('%02d' % int(matchObj.group(1)))
    
    # round url: 
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)-runde/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Round ' + matchObj.group(1).upper()
    
    # group url: https://www.worldfootball.net/schedule/wm-quali-europa-2016-2017-gruppe-a/0/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-gruppe-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Group ' + matchObj.group(1).upper()
    
    # round group url: https://www.worldfootball.net/schedule/wm-quali-asien-2015-2017-3-runde-gruppe-a/2/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)-runde-gruppe-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Round {0} Group {1}'.format(matchObj.group(1).upper(), matchObj.group(2).upper())
    
    # relegation url: https://www.worldfootball.net/schedule/wm-quali-asien-2011-2013-relegation/2/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-relegation/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Relegation'
    
    # cup url: final
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        stage = matchObj.group(1)
        if('finale' in stage or 'endspiel' in stage or 'endrunde' in stage or 'finalrunde' in stage):
            return 'Final'
        elif('entscheidungsspiel' in stage):
            return 'Replays'
        else:
            raise ValueError("Couldn't match stage name in url: {0}".format(url))

# %%
# return selected stage from the tree
def get_selected_stage_from_tree(tree):
    option = tree.find('.//select[@name="runde"]/option[@class="wahl"]')
    stage = option.text_content()[:option.text_content().find('.')]
    return 'Week' + str('%02d' % int(stage))

# %%
def check_stage_name(stage):
    
    stage_allowed_names = ['Week%%', 'Final', 'Semi-finals', 'Quarter-finals', 'Round %%', 'Round of%%', 'Group%%', '3rd place', 'Relegation']
    
    for pattern in stage_allowed_names:
        if('%%' in pattern):
            if pattern.replace('%%','') in stage:
                return
        else:
            if pattern == stage:
                return
    raise ValueError('stage name not allowed: {0}'.format(stage))

# %%
check_stage_name('Group A')
check_stage_name('Round of 16')
check_stage_name('3rd place')

# %%
def format_stage_name(stage):
    dic = {
        '3td place': '3rd place',
        'Third place': '3rd place',
        'Final round': 'Final',
        'Caribbean Quarter-finals': 'Quarter-finals',
        'Caribbean Semi-finals': 'Semi-finals',
        'Caribbean Final': 'Final'
        
    }
    
    if(stage in dic.keys()):
        return dic[stage]
    return stage

# %%
# run the whole tree saver process
def run_tree_saver(conf):

    sections = conf.get_sections()
    ignore_sections = conf.get('general', 'ignore_sections', True)
    #club_cup_list = conf.get('general', 'club_cup_list', True)
    season_min = int(conf.get('general', 'season_min'))
    season_max = int(conf.get('general', 'season_max'))
    
    # open driver
    driver = webdriver.Firefox()

    for section in sections:

        if(section in ignore_sections):
            continue
        
        logWrapper('##########################################################')
        logWrapper('processing section {0}'.format(section))
        logWrapper('##########################################################')
        
        dic = conf.get_section(section)

        for competition in dic.keys():

            logWrapper('**********************************************')
            logWrapper('processing competition {0}'.format(competition))
            logWrapper('**********************************************')
            
            # competition overview url
            ovw_url = website_url + '/competition/' + dic[competition] + '/'

            competition_path = os.path.join(root_path, section, competition)

            # get tree associated to overview url (from drive or from web)
            ovw_tree_file_full_path = os.path.join(competition_path, competition + '_overview.html')
            ovw_tree = get_tree_from_url(driver, ovw_tree_file_full_path, ovw_url)

            # get result url from overview url, that's the current result url (ie: current season, current stage)
            curr_result_url = website_url + get_result_url_from_tree(ovw_tree)

            # get tree associated to current result url
            curr_tree_full_path = os.path.join(competition_path, competition + '_current_result.html')
            curr_tree = get_tree_from_url(driver, curr_tree_full_path , curr_result_url)

            # get dic {season:url} from current result tree
            dic_seasons = get_seasons_dic_from_tree(curr_tree)
            
            for season in dic_seasons.keys():

                try:
                    # check if we process this season (ie: not too old)
                    if(int(season[:4]) < season_min or int(season[:4]) > season_max):
                        logWrapper('ignoring season {0}'.format(season))
                        continue
                    
                    logWrapper('--------------------------------')
                    logWrapper('processing season {0}'.format(season))
                    logWrapper('--------------------------------')
                    
                    season_path = os.path.join(competition_path, season)
                    
                    # default url when season is loaded, usually the final stage or last week of a season
                    season_default_url = website_url + dic_seasons[season]
                    season_default_full_path = os.path.join(season_path, 'season_default.html')
                    last_stage_tree = get_tree_from_url(driver, season_default_full_path , season_default_url)
                                        
                    # this url is usually the last stage url for a given season (or the 'final' url for a cup competition)
                    #stage_url = website_url + dic_seasons[season]
                    #logWrapper('stage url: {0}'.format(stage_url))
                    # get stage from the url itself
                    #stage = match_stage_in_url(stage_url)
                    #check_stage_name(stage)
                    #logWrapper('stage: {0}'.format(stage))                    
                    
                    # get tree associated to season last stage url
                    #last_stage_full_path = os.path.join(season_path, stage + '.html')
                    #last_stage_tree = get_tree_from_url(driver, last_stage_full_path , stage_url)
                    
                    # get dic {stage:url} from last stage tree
                    dic_stages = get_stages_dic_from_tree(last_stage_tree)

                    for stage_as_in_url in dic_stages.keys():

                        try:
                            #stage = format_stage_name(stage_as_in_url)
                            #check_stage_name(stage)
                            
                            logWrapper('processing {0}, season {1}, stage {2}'.format(competition, season, stage_as_in_url))

                            # this url is usually the last stage url for a given season (or the 'final' url for a cup competition)
                            curr_stage_url = website_url + dic_stages[stage_as_in_url]
                            #logWrapper('we are looking for this url: {0}'.format(curr_stage_url))

                            # get tree associated to current stage url
                            curr_stage_full_path = os.path.join(season_path, stage_as_in_url + '.html')
                            #logWrapper('should resolve to path: {0}'.format(curr_stage_full_path))

                            last_stage_tree = get_tree_from_url(driver, curr_stage_full_path , curr_stage_url)
                        except Exception as e:
                            logWrapper("Exception while processing stage {0}: {1}".format(stage, e), level='error')
                            continue
                    
                except Exception as e:
                    logWrapper("Exception while processing season {0}: {1}".format(season, e), level='error')
                    continue
                
    # close driver
    driver.quit()
    logWrapper("Process finished")

# %%
# load conf
conf = ConfHandler(conf_path)
run_tree_saver(conf)
# Out:
# ##########################################################
# processing section world
# ##########################################################
# **********************************************
# processing competition world-cup
# **********************************************
# ignoring season 2022 Qatar
# ignoring season 2018 Russia
# --------------------------------
# processing season 2014 Brazil
# --------------------------------
# processing world-cup, season 2014 Brazil, stage Group A
# we are looking for this url: https://www.worldfootball.net/schedule/wm-2014-in-brasilien-gruppe-a/0/
# Exception while processing season 2014 Brazil: name 'stage' is not defined
# --------------------------------
# processing season 2010 South Africa
# --------------------------------
# processing world-cup, season 2010 South Africa, stage Group A
# we are looking for this url: https://www.worldfootball.net/schedule/wm-2010-in-suedafrika-gruppe-a/0/
# Exception while processing season 2010 South Africa: name 'stage' is not defined
# --------------------------------
# processing season 2006 Germany
# --------------------------------
# processing world-cup, season 2006 Germany, stage Group A
# we are looking for this url: https://www.worldfootball.net/schedule/wm-2006-in-deutschland-gruppe-a/0/
# Exception while processing season 2006 Germany: name 'stage' is not defined
# --------------------------------
# processing season 2002 Japan-South Korea
# --------------------------------
# Exception while processing season 2002 Japan-South Korea: Message: Failed to decode response from marionette
#
# --------------------------------
# processing season 1998 France
# --------------------------------
# Exception while processing season 1998 France: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1994 USA
# --------------------------------
# Exception while processing season 1994 USA: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1990 Italy
# --------------------------------
# Exception while processing season 1990 Italy: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1986 Mexico
# --------------------------------
# Exception while processing season 1986 Mexico: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1982 Spain
# --------------------------------
# Exception while processing season 1982 Spain: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1978 Argentina
# --------------------------------
# Exception while processing season 1978 Argentina: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1974 Germany
# --------------------------------
# Exception while processing season 1974 Germany: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1970 Mexico
# --------------------------------
# Exception while processing season 1970 Mexico: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1966 England
# --------------------------------
# Exception while processing season 1966 England: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1962 Chile
# --------------------------------
# Exception while processing season 1962 Chile: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1958 Sweden
# --------------------------------
# Exception while processing season 1958 Sweden: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1954 Switzerland
# --------------------------------
# Exception while processing season 1954 Switzerland: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1950 Brazil
# --------------------------------
# Exception while processing season 1950 Brazil: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1938 France
# --------------------------------
# Exception while processing season 1938 France: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1934 Italy
# --------------------------------
# Exception while processing season 1934 Italy: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1930 Uruguay
# --------------------------------
# Exception while processing season 1930 Uruguay: Message: Tried to run command without establishing a connection
#
# **********************************************
# processing competition world-cup-qualifier-europe
# **********************************************
# --------------------------------
# processing season 2016-2017
# --------------------------------
# Exception while processing season 2016-2017: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2012-2013
# --------------------------------
# Exception while processing season 2012-2013: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2008-2009
# --------------------------------
# Exception while processing season 2008-2009: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2004-2005
# --------------------------------
# Exception while processing season 2004-2005: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2000-2001
# --------------------------------
# Exception while processing season 2000-2001: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1996-1997
# --------------------------------
# Exception while processing season 1996-1997: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1992-1993
# --------------------------------
# Exception while processing season 1992-1993: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1988-1989
# --------------------------------
# Exception while processing season 1988-1989: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1984-1985
# --------------------------------
# Exception while processing season 1984-1985: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1980-1981
# --------------------------------
# Exception while processing season 1980-1981: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1976-1977
# --------------------------------
# Exception while processing season 1976-1977: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1972-1973
# --------------------------------
# Exception while processing season 1972-1973: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1968-1969
# --------------------------------
# Exception while processing season 1968-1969: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1964-1965
# --------------------------------
# Exception while processing season 1964-1965: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1960-1961
# --------------------------------
# Exception while processing season 1960-1961: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1956-1957
# --------------------------------
# Exception while processing season 1956-1957: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1953-1954
# --------------------------------
# Exception while processing season 1953-1954: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1949-1950
# --------------------------------
# Exception while processing season 1949-1950: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1937-1938
# --------------------------------
# Exception while processing season 1937-1938: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1933-1934
# --------------------------------
# Exception while processing season 1933-1934: Message: Tried to run command without establishing a connection
#
# **********************************************
# processing competition world-cup-qualifier-south-america
# **********************************************
# --------------------------------
# processing season 2015-2017
# --------------------------------
# Exception while processing season 2015-2017: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2011-2013
# --------------------------------
# Exception while processing season 2011-2013: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2008-2009
# --------------------------------
# Exception while processing season 2008-2009: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2004-2005
# --------------------------------
# Exception while processing season 2004-2005: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2000-2001
# --------------------------------
# Exception while processing season 2000-2001: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1996-1997
# --------------------------------
# Exception while processing season 1996-1997: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1993
# --------------------------------
# Exception while processing season 1993: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1989
# --------------------------------
# Exception while processing season 1989: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1985
# --------------------------------
# Exception while processing season 1985: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1981
# --------------------------------
# Exception while processing season 1981: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1977
# --------------------------------
# Exception while processing season 1977: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1973
# --------------------------------
# Exception while processing season 1973: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1969
# --------------------------------
# Exception while processing season 1969: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1965
# --------------------------------
# Exception while processing season 1965: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1960-1961
# --------------------------------
# Exception while processing season 1960-1961: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1957
# --------------------------------
# Exception while processing season 1957: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1954
# --------------------------------
# Exception while processing season 1954: Message: Tried to run command without establishing a connection
#
# **********************************************
# processing competition world-cup-qualifier-asia
# **********************************************
# --------------------------------
# processing season 2015-2017
# --------------------------------
# Exception while processing season 2015-2017: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2011-2013
# --------------------------------
# Exception while processing season 2011-2013: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2008-2009
# --------------------------------
# Exception while processing season 2008-2009: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2004-2005
# --------------------------------
# Exception while processing season 2004-2005: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2000-2001
# --------------------------------
# Exception while processing season 2000-2001: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1996-1997
# --------------------------------
# Exception while processing season 1996-1997: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1992-1993
# --------------------------------
# Exception while processing season 1992-1993: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1988-1989
# --------------------------------
# Exception while processing season 1988-1989: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1984-1985
# --------------------------------
# Exception while processing season 1984-1985: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1964-1965
# --------------------------------
# Exception while processing season 1964-1965: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1960-1961
# --------------------------------
# Exception while processing season 1960-1961: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1954
# --------------------------------
# Exception while processing season 1954: Message: Tried to run command without establishing a connection
#
# **********************************************
# processing competition world-cup-qualifier-concacaf
# **********************************************
# --------------------------------
# processing season 2015-2017
# --------------------------------
# Exception while processing season 2015-2017: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2011-2013
# --------------------------------
# Exception while processing season 2011-2013: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2008-2009
# --------------------------------
# Exception while processing season 2008-2009: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2004-2005
# --------------------------------
# Exception while processing season 2004-2005: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2000-2001
# --------------------------------
# Exception while processing season 2000-2001: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1996-1997
# --------------------------------
# Exception while processing season 1996-1997: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1992-1993
# --------------------------------
# Exception while processing season 1992-1993: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1965
# --------------------------------
# Exception while processing season 1965: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1960-1961
# --------------------------------
# Exception while processing season 1960-1961: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1957
# --------------------------------
# Exception while processing season 1957: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1953-1954
# --------------------------------
# Exception while processing season 1953-1954: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1949
# --------------------------------
# Exception while processing season 1949: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1934
# --------------------------------
# Exception while processing season 1934: Message: Tried to run command without establishing a connection
#
# **********************************************
# processing competition world-cup-qualifier-africa
# **********************************************
# --------------------------------
# processing season 2015-2017
# --------------------------------
# Exception while processing season 2015-2017: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2011-2013
# --------------------------------
# Exception while processing season 2011-2013: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2008-2009
# --------------------------------
# Exception while processing season 2008-2009: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2004-2005
# --------------------------------
# Exception while processing season 2004-2005: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2000-2001
# --------------------------------
# Exception while processing season 2000-2001: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1996-1997
# --------------------------------
# Exception while processing season 1996-1997: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1992-1993
# --------------------------------
# Exception while processing season 1992-1993: Message: Tried to run command without establishing a connection
#
# **********************************************
# processing competition world-cup-qualifier-oceania
# **********************************************
# --------------------------------
# processing season 2015-2017
# --------------------------------
# Exception while processing season 2015-2017: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2011-2012
# --------------------------------
# Exception while processing season 2011-2012: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2007-2008
# --------------------------------
# Exception while processing season 2007-2008: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2004-2005
# --------------------------------
# Exception while processing season 2004-2005: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2001
# --------------------------------
# Exception while processing season 2001: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1996-1997
# --------------------------------
# Exception while processing season 1996-1997: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1992-1993
# --------------------------------
# Exception while processing season 1992-1993: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1988-1989
# --------------------------------
# Exception while processing season 1988-1989: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1985
# --------------------------------
# Exception while processing season 1985: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1981
# --------------------------------
# Exception while processing season 1981: Message: Tried to run command without establishing a connection
#
# **********************************************
# processing competition world-cup-qualifier-play-offs
# **********************************************
# --------------------------------
# processing season 2013
# --------------------------------
# Exception while processing season 2013: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2009
# --------------------------------
# Exception while processing season 2009: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2005
# --------------------------------
# Exception while processing season 2005: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 2001
# --------------------------------
# Exception while processing season 2001: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1997
# --------------------------------
# Exception while processing season 1997: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1993
# --------------------------------
# Exception while processing season 1993: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1989
# --------------------------------
# Exception while processing season 1989: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1985
# --------------------------------
# Exception while processing season 1985: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1977
# --------------------------------
# Exception while processing season 1977: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1973
# --------------------------------
# Exception while processing season 1973: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1961
# --------------------------------
# Exception while processing season 1961: Message: Tried to run command without establishing a connection
#
# --------------------------------
# processing season 1958
# --------------------------------
# Exception while processing season 1958: Message: Tried to run command without establishing a connection
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-20-132b942ffd45> in <module>()
#       1 # load conf
#       2 conf = ConfHandler(conf_path)
# ----> 3 run_tree_saver(conf)
#
# <ipython-input-19-8f1ce8fd1bee> in run_tree_saver(conf)
#     107
#     108     # close driver
# --> 109     driver.quit()
#     110     logWrapper("Process finished")
#     111
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in quit(self)
#     179         """Quits the driver and close every associated window."""
#     180         try:
# --> 181             RemoteWebDriver.quit(self)
#     182         except (http_client.BadStatusLine, socket.error):
#     183             # Happens if Firefox shutsdown before we've read the response from
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in quit(self)
#     545         """
#     546         try:
# --> 547             self.execute(Command.QUIT)
#     548         finally:
#     549             self.stop_client()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     250         response = self.command_executor.execute(driver_command, params)
#     251         if response:
# --> 252             self.error_handler.check_response(response)
#     253             response['value'] = self._unwrap_value(
#     254                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: Tried to run command without establishing a connection
