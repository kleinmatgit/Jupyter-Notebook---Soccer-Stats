# %% [markdown]
# # Introduction

# %% [markdown]
# The goal of this notebook is to analyse worldfootball.net urls and save down results page into tree structure. This will be used later on to get results and save it under a more readable format (csv).
#
# The trees will be saved on the drive under a specific folder hierarchy:
# zone -> competition -> season -> stage.html
#
# for instance:
# france -> ligue1 -> 2016-2017 -> Week01.html
#
# Stage name is then the tree file name.

# %% [markdown]
# # Import

# %%
import lxml.html as lh
import lxml.etree as et
from selenium import webdriver
import time
import pickle
import traceback
import logging
import os.path
import configparser
import os
import re
import datetime

# %% [markdown]
# # Params

# %%
root_path = 'L:/Dev/Sandbox/Apps Development/SoccerWebApp/PySoccer/WorldFootballDotNet/'
conf_path = os.path.join(root_path, '_conf','worldfootball.ini')
log_path = os.path.join(root_path, '_logs')
website_url = 'https://www.worldfootball.net'

# %% [markdown]
# # Logging

# %%
logger = logging.getLogger('myapp')
timestamp = datetime.datetime.now().strftime('%H%M%S')
hdlr = logging.FileHandler(os.path.join(log_path,'worldfootballnet_TreeSaver_' + timestamp + '.log'))
formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
hdlr.setFormatter(formatter)
logger.addHandler(hdlr) 
logger.setLevel(logging.DEBUG)

# %%
def logWrapper(message, level="info", print_console=True):
    if(print_console):
        print(message)
    if(level=="info"):
        logger.info(message)
    elif(level=="warning"):
        logger.warning(message)
    elif(level=="debug"):
        logger.debug(message)
    elif(level=="error"):
        logger.error(message)

# %%
#logger.error("test error")
#logger.warning("this is a warning")
#logger.info("this is just info")
#logger.debug("this is debug")
#logWrapper('hello world')
#logWrapper('message')

# %% [markdown]
# # Conf

# %%
class ConfHandler():

    dicSections = {}
    
    def __init__(self,file_full_path):

        if not os.path.exists(file_full_path):
            raise Exception('path not correct: {0}'.format(file_full_path))
        
        config = configparser.ConfigParser()
        config.read(file_full_path)
        
        for s in config.sections():
            dicParams = {}
            for p in config[s]:
                dicParams[p] = config[s][p]
            self.dicSections[s] = dicParams

    def get(self,section,param, is_param_list = False):
        if section not in self.dicSections.keys():
            return None
        if param not in self.dicSections[section].keys():
            return None
        if self.dicSections[section][param]=='':
            return None
        if(is_param_list):
            return self.dicSections[section][param].replace(' ','').split(',')
        return self.dicSections[section][param]
    
    def get_section(self,section):
        if section not in self.dicSections.keys():
            return None
        return self.dicSections[section]
    
    def get_sections(self):
        return sorted(list(self.dicSections.keys()))

# %%
# test conf
conf = ConfHandler(conf_path)

# return setting within section
print(conf.get('france','ligue1'))

# france section only
dic = conf.get_section('france')
print(dic)

# all sections
sections = conf.get_sections()
print(sections)

# filter section
print(conf.get('general', 'section_filter_for_tree_saving', True))

# this section doesn't exist, should return None:
print(conf.get('cup', 'club_cup_list', True))

# this setting doesn't exist within existing section, should return None:
print(conf.get('general', 'club_cup_list', True))

# setting exists, but is empty -> should return None
print(conf.get('general', 'test_empty_param'))

# setting exists, but is empty -> should return None
print(conf.get('general', 'test_empty_param', True))
# Out:
# fra-ligue-1
# {'ligue1': 'fra-ligue-1', 'coupe-de-france': 'fra-coupe-de-france', 'coupe-de-la-ligue': 'fra-coupe-de-la-ligue', 'trophee-des-champions': 'fra-trophee-des-champions'}
# ['england', 'europe', 'france', 'general', 'germany', 'italy', 'netherlands', 'portugal', 'spain', 'world']
# None
# None
# None
# None
# None

# %% [markdown]
# # Functions

# %% [markdown]
# ## [selenium_url_to_tree] download url final output as a tree

# %%
# get url html as elementtree using selenium.webdriver
def selenium_url_to_tree(driver, url):
    driver.get(url)
    time.sleep(int(conf.get('general', 'connection_waiting_time')))
    htmlSource = driver.page_source
    tree = lh.fromstring(htmlSource)
    return tree

# HOW IT WORKS....
# open driver: that will open firefox window
#driver = webdriver.Firefox()

# construct the trees only once
#results_tree = selenium_url_to_tree(driver,week_url)

# close firefox window once done
#driver.quit()

# %%
# return html page as a tree.
# the tree object will be cached to drive so next call won't require web call
def get_tree_from_url(driver, filename, url):
    
    logWrapper("Trying to load url {0}...".format(url), level='info')
                            
    # file doesn't exist, we will have to do a web call
    if(not os.path.isfile(filename)):
        
        logWrapper("File don't exist: {0}".format(filename), level='info')
        
        # create folder if not done already
        if not os.path.exists(os.path.dirname(filename)):
            try:
                os.makedirs(os.path.dirname(filename))
            except OSError as exc: # Guard against race condition
                if exc.errno != errno.EEXIST:
                    raise
        
        # load up url in web browser
        logWrapper("Loading url in web browser: {0}".format(url), level='info')
        tree = selenium_url_to_tree(driver,url)
        
        # save it down to the drive
        tree.getroottree().write(filename)
        
        if(not os.path.isfile(filename)):
            raise
        
    # return the loaded tree
    return lh.fromstring(open(filename, 'r').read())

# %%
def get_result_url_from_tree(tree):
    return tree.find('.//div[@class="navibox2"]//div[@class="data"]/ul[2]/li/a').attrib['href']

# %%
# construct dictionary of {season: url}
def get_seasons_dic_from_tree(tree):
    options = tree.findall('.//select[@name="saison"]/option')
    dic = {}
    for option in options:
        season = option.text_content().replace('/','-')
        dic[season] = option.attrib['value']
    return dic

# %%
# construct dictionary of {stage: url}
def get_stages_dic_from_tree(tree):
    
    dic = {}
    
    is_cup = False
    
    # assume we are looking at a 'league' tree
    options = tree.findall('.//select[@name="runde"]/option')
    
    if len(options) == 0:
        # now trying to see if we are looking at a 'cup' tree
        options = tree.findall('.//select[@name="phase"]/option')
        
        if len(options) == 0:
            raise
        else:
            is_cup = True
    
    for option in options:
        stage = option.text_content()
        if(is_cup):
            dic[stage] = option.attrib['value']
        else:
            stage = stage[:stage.find('.')]
            dic['Week' + str('%02d' % int(stage))] = option.attrib['value']
    return dic

# %%
# use regex to find season in an url (ie: 2016-2017)
def match_season(url):
    matchObj = re.match(r'.*([1-3][0-9]{3}-[1-3][0-9]{3}).*', url)
    if not matchObj:
        # sometime we get only year instead of season
        matchObj = re.match(r'.*([1-3][0-9]{3}).*', url)
        if not matchObj:
            raise
    return matchObj.group(1)

# %%
# use regex to find stage in an url (ie: '1' or '38' or 'final')
def match_stage_in_url(url):
    
    # league url
    matchObj = re.match(r'.*[1-3][0-9]{3}-[1-3][0-9]{3}-spieltag/(\b\d{1,2}\b)/', url)
    if matchObj:
        return 'Week' + str('%02d' % int(matchObj.group(1)))
    
    # qualification url: https://www.worldfootball.net/schedule/wm-quali-suedamerika-2010-spieltag/18/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-spieltag/(\b\d{1,2}\b)/', url)
    if matchObj:
        return 'Week' + str('%02d' % int(matchObj.group(1)))
    
    # round url: 
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)-runde/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Round ' + matchObj.group(1).upper()
    
    # group url: https://www.worldfootball.net/schedule/wm-quali-europa-2016-2017-gruppe-a/0/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-gruppe-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Group ' + matchObj.group(1).upper()
    
    # round group url: https://www.worldfootball.net/schedule/wm-quali-asien-2015-2017-3-runde-gruppe-a/2/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)-runde-gruppe-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Round {0} Group {1}'.format(matchObj.group(1).upper(), matchObj.group(2).upper())
    
    # relegation url: https://www.worldfootball.net/schedule/wm-quali-asien-2011-2013-relegation/2/
    matchObj = re.match(r'.*-[1-3][0-9]{3}-relegation/\b\d{1,2}\b/', url)
    if matchObj:
        return 'Relegation'
    
    # cup url: final
    matchObj = re.match(r'.*-[1-3][0-9]{3}-(.*)/\b\d{1,2}\b/', url)
    if matchObj:
        stage = matchObj.group(1)
        if('finale' in stage or 'endspiel' in stage or 'endrunde' in stage or 'finalrunde' in stage):
            return 'Final'
        elif('entscheidungsspiel' in stage):
            return 'Replays'
        else:
            raise ValueError("Couldn't match stage name in url: {0}".format(url))

# %%
# return selected stage from the tree
def get_selected_stage_from_tree(tree):
    option = tree.find('.//select[@name="runde"]/option[@class="wahl"]')
    stage = option.text_content()[:option.text_content().find('.')]
    return 'Week' + str('%02d' % int(stage))

# %%
def check_stage_name(stage):
    
    stage_allowed_names = ['Week%%', 'Final', 'Semi-finals', 'Quarter-finals', 'Round %%', 'Round of%%', 'Group%%', '3rd place', 'Relegation']
    
    for pattern in stage_allowed_names:
        if('%%' in pattern):
            if pattern.replace('%%','') in stage:
                return
        else:
            if pattern == stage:
                return
    raise ValueError('stage name not allowed: {0}'.format(stage))

# %%
check_stage_name('Group A')
check_stage_name('Round of 16')
check_stage_name('3rd place')

# %%
def format_stage_name(stage):
    dic = {
        '3td place': '3rd place',
        'Third place': '3rd place',
        'Final round': 'Final',
        'Caribbean Quarter-finals': 'Quarter-finals',
        'Caribbean Semi-finals': 'Semi-finals',
        'Caribbean Final': 'Final'
        
    }
    
    if(stage in dic.keys()):
        return dic[stage]
    return stage

# %%
def get_sections_to_process(conf):
    sections = conf.get_sections()
    ignore_zones = conf.get('general', 'ignore_sections_for_tree_saving', True)
    zone_filter = conf.get('general', 'section_filter_for_tree_saving', True)
    if zone_filter != None:
        sections = list(set(sections) & set(zone_filter))
    elif ignore_zones != None:
        sections = list(set(sections) - set(ignore_zones))
    return sections

# %%
# run the whole tree saver process
def run_tree_saver(conf):

    season_min = int(conf.get('general', 'season_min'))
    season_max = int(conf.get('general', 'season_max'))
    
    sections = get_sections_to_process(conf)
    print('sections: {0}'.format(sections))        
    
    # open driver
    driver = webdriver.Firefox()
    
    for section in sections:

        #if(section in ignore_zones):
        #    continue
        
        logWrapper('##########################################################')
        logWrapper('processing section {0}'.format(section))
        logWrapper('##########################################################')
        
        dic = conf.get_section(section)

        for competition in dic.keys():

            logWrapper('**********************************************')
            logWrapper('processing competition {0}'.format(competition))
            logWrapper('**********************************************')
            
            # competition overview url
            ovw_url = website_url + '/competition/' + dic[competition] + '/'

            competition_path = os.path.join(root_path, section, competition)

            # get tree associated to overview url (from drive or from web)
            ovw_tree_file_full_path = os.path.join(competition_path, competition + '_overview.html')
            ovw_tree = get_tree_from_url(driver, ovw_tree_file_full_path, ovw_url)

            # get result url from overview url, that's the current result url (ie: current season, current stage)
            curr_result_url = website_url + get_result_url_from_tree(ovw_tree)

            # get tree associated to current result url
            curr_tree_full_path = os.path.join(competition_path, competition + '_current_result.html')
            curr_tree = get_tree_from_url(driver, curr_tree_full_path , curr_result_url)

            # get dic {season:url} from current result tree
            dic_seasons = get_seasons_dic_from_tree(curr_tree)
            
            for season in dic_seasons.keys():

                try:
                    # check if we process this season (ie: not too old)
                    if(int(season[:4]) < season_min or int(season[:4]) > season_max):
                        logWrapper('ignoring season {0}'.format(season))
                        continue
                    
                    logWrapper('--------------------------------')
                    logWrapper('processing season {0}'.format(season))
                    logWrapper('--------------------------------')
                    
                    season_path = os.path.join(competition_path, season)
                    
                    # default url when season is loaded, usually the final stage or last week of a season
                    season_default_url = website_url + dic_seasons[season]
                    season_default_full_path = os.path.join(season_path, 'season_default.html')
                    last_stage_tree = get_tree_from_url(driver, season_default_full_path , season_default_url)
                                        
                    # get dic {stage:url} from last stage tree
                    dic_stages = get_stages_dic_from_tree(last_stage_tree)

                    for stage_as_in_url in dic_stages.keys():

                        try:
                            logWrapper('processing {0}, season {1}, stage {2}'.format(competition, season, stage_as_in_url))

                            # this url is usually the last stage url for a given season (or the 'final' url for a cup competition)
                            curr_stage_url = website_url + dic_stages[stage_as_in_url]
                            #logWrapper('we are looking for this url: {0}'.format(curr_stage_url))

                            # get tree associated to current stage url
                            curr_stage_full_path = os.path.join(season_path, stage_as_in_url + '.html')
                            #logWrapper('should resolve to path: {0}'.format(curr_stage_full_path))

                            last_stage_tree = get_tree_from_url(driver, curr_stage_full_path , curr_stage_url)
                        except Exception as e:
                            logWrapper("Exception while processing stage {0}: {1}".format(stage, e), level='error')
                            continue
                    
                except Exception as e:
                    logWrapper("Exception while processing season {0}: {1}".format(season, e), level='error')
                    continue
                
    # close driver
    driver.quit()
    logWrapper("Process finished")

# %%
run_tree_saver(ConfHandler(conf_path))
# Out:
# sections: ['spain', 'europe']
# ##########################################################
# processing section spain
# ##########################################################
# **********************************************
# processing competition la-liga
# **********************************************
# Trying to load url https://www.worldfootball.net/competition/esp-primera-division/...
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2017-2018-spieltag/2/...
# ignoring season 2017-2018
# --------------------------------
# processing season 2016-2017
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/38/...
# processing la-liga, season 2016-2017, stage Week01
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/1/...
# processing la-liga, season 2016-2017, stage Week02
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/2/...
# processing la-liga, season 2016-2017, stage Week03
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/3/...
# processing la-liga, season 2016-2017, stage Week04
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/4/...
# processing la-liga, season 2016-2017, stage Week05
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/5/...
# processing la-liga, season 2016-2017, stage Week06
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/6/...
# processing la-liga, season 2016-2017, stage Week07
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/7/...
# processing la-liga, season 2016-2017, stage Week08
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/8/...
# processing la-liga, season 2016-2017, stage Week09
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/9/...
# processing la-liga, season 2016-2017, stage Week10
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/10/...
# processing la-liga, season 2016-2017, stage Week11
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/11/...
# processing la-liga, season 2016-2017, stage Week12
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/12/...
# processing la-liga, season 2016-2017, stage Week13
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/13/...
# processing la-liga, season 2016-2017, stage Week14
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/14/...
# processing la-liga, season 2016-2017, stage Week15
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/15/...
# processing la-liga, season 2016-2017, stage Week16
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/16/...
# processing la-liga, season 2016-2017, stage Week17
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/17/...
# processing la-liga, season 2016-2017, stage Week18
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/18/...
# processing la-liga, season 2016-2017, stage Week19
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/19/...
# processing la-liga, season 2016-2017, stage Week20
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/20/...
# processing la-liga, season 2016-2017, stage Week21
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/21/...
# processing la-liga, season 2016-2017, stage Week22
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/22/...
# processing la-liga, season 2016-2017, stage Week23
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/23/...
# processing la-liga, season 2016-2017, stage Week24
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/24/...
# processing la-liga, season 2016-2017, stage Week25
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/25/...
# processing la-liga, season 2016-2017, stage Week26
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/26/...
# processing la-liga, season 2016-2017, stage Week27
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/27/...
# processing la-liga, season 2016-2017, stage Week28
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/28/...
# processing la-liga, season 2016-2017, stage Week29
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/29/...
# processing la-liga, season 2016-2017, stage Week30
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/30/...
# processing la-liga, season 2016-2017, stage Week31
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/31/...
# processing la-liga, season 2016-2017, stage Week32
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/32/...
# processing la-liga, season 2016-2017, stage Week33
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/33/...
# processing la-liga, season 2016-2017, stage Week34
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/34/...
# processing la-liga, season 2016-2017, stage Week35
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/35/...
# processing la-liga, season 2016-2017, stage Week36
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/36/...
# processing la-liga, season 2016-2017, stage Week37
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/37/...
# processing la-liga, season 2016-2017, stage Week38
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2016-2017-spieltag_2/38/...
# --------------------------------
# processing season 2015-2016
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/38/...
# processing la-liga, season 2015-2016, stage Week01
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/1/...
# processing la-liga, season 2015-2016, stage Week02
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/2/...
# processing la-liga, season 2015-2016, stage Week03
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/3/...
# processing la-liga, season 2015-2016, stage Week04
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/4/...
# processing la-liga, season 2015-2016, stage Week05
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/5/...
# processing la-liga, season 2015-2016, stage Week06
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/6/...
# processing la-liga, season 2015-2016, stage Week07
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/7/...
# processing la-liga, season 2015-2016, stage Week08
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/8/...
# processing la-liga, season 2015-2016, stage Week09
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/9/...
# processing la-liga, season 2015-2016, stage Week10
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/10/...
# processing la-liga, season 2015-2016, stage Week11
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/11/...
# processing la-liga, season 2015-2016, stage Week12
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/12/...
# processing la-liga, season 2015-2016, stage Week13
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/13/...
# processing la-liga, season 2015-2016, stage Week14
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/14/...
# processing la-liga, season 2015-2016, stage Week15
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/15/...
# processing la-liga, season 2015-2016, stage Week16
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/16/...
# processing la-liga, season 2015-2016, stage Week17
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/17/...
# processing la-liga, season 2015-2016, stage Week18
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/18/...
# processing la-liga, season 2015-2016, stage Week19
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/19/...
# processing la-liga, season 2015-2016, stage Week20
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/20/...
# processing la-liga, season 2015-2016, stage Week21
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/21/...
# processing la-liga, season 2015-2016, stage Week22
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/22/...
# processing la-liga, season 2015-2016, stage Week23
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/23/...
# processing la-liga, season 2015-2016, stage Week24
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/24/...
# processing la-liga, season 2015-2016, stage Week25
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/25/...
# processing la-liga, season 2015-2016, stage Week26
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/26/...
# processing la-liga, season 2015-2016, stage Week27
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/27/...
# processing la-liga, season 2015-2016, stage Week28
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/28/...
# processing la-liga, season 2015-2016, stage Week29
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/29/...
# processing la-liga, season 2015-2016, stage Week30
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/30/...
# processing la-liga, season 2015-2016, stage Week31
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/31/...
# processing la-liga, season 2015-2016, stage Week32
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/32/...
# processing la-liga, season 2015-2016, stage Week33
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/33/...
# processing la-liga, season 2015-2016, stage Week34
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/34/...
# processing la-liga, season 2015-2016, stage Week35
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/35/...
# processing la-liga, season 2015-2016, stage Week36
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/36/...
# processing la-liga, season 2015-2016, stage Week37
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/37/...
# processing la-liga, season 2015-2016, stage Week38
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2015-2016-spieltag/38/...
# --------------------------------
# processing season 2014-2015
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/38/...
# processing la-liga, season 2014-2015, stage Week01
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/1/...
# processing la-liga, season 2014-2015, stage Week02
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/2/...
# processing la-liga, season 2014-2015, stage Week03
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/3/...
# processing la-liga, season 2014-2015, stage Week04
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/4/...
# processing la-liga, season 2014-2015, stage Week05
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/5/...
# processing la-liga, season 2014-2015, stage Week06
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/6/...
# processing la-liga, season 2014-2015, stage Week07
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/7/...
# processing la-liga, season 2014-2015, stage Week08
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/8/...
# processing la-liga, season 2014-2015, stage Week09
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/9/...
# processing la-liga, season 2014-2015, stage Week10
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/10/...
# processing la-liga, season 2014-2015, stage Week11
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/11/...
# processing la-liga, season 2014-2015, stage Week12
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/12/...
# processing la-liga, season 2014-2015, stage Week13
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/13/...
# processing la-liga, season 2014-2015, stage Week14
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/14/...
# processing la-liga, season 2014-2015, stage Week15
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/15/...
# processing la-liga, season 2014-2015, stage Week16
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/16/...
# processing la-liga, season 2014-2015, stage Week17
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/17/...
# processing la-liga, season 2014-2015, stage Week18
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/18/...
# processing la-liga, season 2014-2015, stage Week19
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/19/...
# processing la-liga, season 2014-2015, stage Week20
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/20/...
# processing la-liga, season 2014-2015, stage Week21
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/21/...
# processing la-liga, season 2014-2015, stage Week22
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/22/...
# processing la-liga, season 2014-2015, stage Week23
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/23/...
# processing la-liga, season 2014-2015, stage Week24
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/24/...
# processing la-liga, season 2014-2015, stage Week25
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/25/...
# processing la-liga, season 2014-2015, stage Week26
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/26/...
# processing la-liga, season 2014-2015, stage Week27
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/27/...
# processing la-liga, season 2014-2015, stage Week28
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/28/...
# processing la-liga, season 2014-2015, stage Week29
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/29/...
# processing la-liga, season 2014-2015, stage Week30
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/30/...
# processing la-liga, season 2014-2015, stage Week31
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/31/...
# processing la-liga, season 2014-2015, stage Week32
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/32/...
# processing la-liga, season 2014-2015, stage Week33
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/33/...
# processing la-liga, season 2014-2015, stage Week34
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/34/...
# processing la-liga, season 2014-2015, stage Week35
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/35/...
# processing la-liga, season 2014-2015, stage Week36
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/36/...
# processing la-liga, season 2014-2015, stage Week37
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/37/...
# processing la-liga, season 2014-2015, stage Week38
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2014-2015-spieltag/38/...
# --------------------------------
# processing season 2013-2014
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/38/...
# processing la-liga, season 2013-2014, stage Week01
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/1/...
# processing la-liga, season 2013-2014, stage Week02
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/2/...
# processing la-liga, season 2013-2014, stage Week03
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/3/...
# processing la-liga, season 2013-2014, stage Week04
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/4/...
# processing la-liga, season 2013-2014, stage Week05
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/5/...
# processing la-liga, season 2013-2014, stage Week06
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/6/...
# processing la-liga, season 2013-2014, stage Week07
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/7/...
# processing la-liga, season 2013-2014, stage Week08
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/8/...
# processing la-liga, season 2013-2014, stage Week09
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/9/...
# processing la-liga, season 2013-2014, stage Week10
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/10/...
# processing la-liga, season 2013-2014, stage Week11
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/11/...
# processing la-liga, season 2013-2014, stage Week12
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/12/...
# processing la-liga, season 2013-2014, stage Week13
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/13/...
# processing la-liga, season 2013-2014, stage Week14
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/14/...
# processing la-liga, season 2013-2014, stage Week15
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/15/...
# processing la-liga, season 2013-2014, stage Week16
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/16/...
# processing la-liga, season 2013-2014, stage Week17
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/17/...
# processing la-liga, season 2013-2014, stage Week18
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/18/...
# processing la-liga, season 2013-2014, stage Week19
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/19/...
# processing la-liga, season 2013-2014, stage Week20
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/20/...
# processing la-liga, season 2013-2014, stage Week21
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/21/...
# processing la-liga, season 2013-2014, stage Week22
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/22/...
# processing la-liga, season 2013-2014, stage Week23
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/23/...
# processing la-liga, season 2013-2014, stage Week24
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/24/...
# processing la-liga, season 2013-2014, stage Week25
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/25/...
# processing la-liga, season 2013-2014, stage Week26
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/26/...
# processing la-liga, season 2013-2014, stage Week27
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/27/...
# processing la-liga, season 2013-2014, stage Week28
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/28/...
# processing la-liga, season 2013-2014, stage Week29
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/29/...
# processing la-liga, season 2013-2014, stage Week30
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/30/...
# processing la-liga, season 2013-2014, stage Week31
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/31/...
# processing la-liga, season 2013-2014, stage Week32
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/32/...
# processing la-liga, season 2013-2014, stage Week33
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/33/...
# processing la-liga, season 2013-2014, stage Week34
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/34/...
# processing la-liga, season 2013-2014, stage Week35
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/35/...
# processing la-liga, season 2013-2014, stage Week36
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/36/...
# processing la-liga, season 2013-2014, stage Week37
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/37/...
# processing la-liga, season 2013-2014, stage Week38
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2013-2014-spieltag/38/...
# --------------------------------
# processing season 2012-2013
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/38/...
# processing la-liga, season 2012-2013, stage Week01
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/1/...
# processing la-liga, season 2012-2013, stage Week02
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/2/...
# processing la-liga, season 2012-2013, stage Week03
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/3/...
# processing la-liga, season 2012-2013, stage Week04
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/4/...
# processing la-liga, season 2012-2013, stage Week05
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/5/...
# processing la-liga, season 2012-2013, stage Week06
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/6/...
# processing la-liga, season 2012-2013, stage Week07
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/7/...
# processing la-liga, season 2012-2013, stage Week08
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/8/...
# processing la-liga, season 2012-2013, stage Week09
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/9/...
# processing la-liga, season 2012-2013, stage Week10
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/10/...
# processing la-liga, season 2012-2013, stage Week11
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/11/...
# processing la-liga, season 2012-2013, stage Week12
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/12/...
# processing la-liga, season 2012-2013, stage Week13
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/13/...
# processing la-liga, season 2012-2013, stage Week14
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/14/...
# processing la-liga, season 2012-2013, stage Week15
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/15/...
# processing la-liga, season 2012-2013, stage Week16
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/16/...
# processing la-liga, season 2012-2013, stage Week17
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/17/...
# processing la-liga, season 2012-2013, stage Week18
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/18/...
# processing la-liga, season 2012-2013, stage Week19
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/19/...
# processing la-liga, season 2012-2013, stage Week20
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/20/...
# processing la-liga, season 2012-2013, stage Week21
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/21/...
# processing la-liga, season 2012-2013, stage Week22
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/22/...
# processing la-liga, season 2012-2013, stage Week23
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/23/...
# processing la-liga, season 2012-2013, stage Week24
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/24/...
# processing la-liga, season 2012-2013, stage Week25
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/25/...
# processing la-liga, season 2012-2013, stage Week26
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/26/...
# processing la-liga, season 2012-2013, stage Week27
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/27/...
# processing la-liga, season 2012-2013, stage Week28
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/28/...
# processing la-liga, season 2012-2013, stage Week29
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/29/...
# processing la-liga, season 2012-2013, stage Week30
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/30/...
# processing la-liga, season 2012-2013, stage Week31
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/31/...
# processing la-liga, season 2012-2013, stage Week32
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/32/...
# processing la-liga, season 2012-2013, stage Week33
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/33/...
# processing la-liga, season 2012-2013, stage Week34
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/34/...
# processing la-liga, season 2012-2013, stage Week35
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/35/...
# processing la-liga, season 2012-2013, stage Week36
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/36/...
# processing la-liga, season 2012-2013, stage Week37
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/37/...
# processing la-liga, season 2012-2013, stage Week38
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2012-2013-spieltag/38/...
# --------------------------------
# processing season 2011-2012
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/38/...
# processing la-liga, season 2011-2012, stage Week01
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/1/...
# processing la-liga, season 2011-2012, stage Week02
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/2/...
# processing la-liga, season 2011-2012, stage Week03
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/3/...
# processing la-liga, season 2011-2012, stage Week04
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/4/...
# processing la-liga, season 2011-2012, stage Week05
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/5/...
# processing la-liga, season 2011-2012, stage Week06
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/6/...
# processing la-liga, season 2011-2012, stage Week07
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/7/...
# processing la-liga, season 2011-2012, stage Week08
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/8/...
# processing la-liga, season 2011-2012, stage Week09
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/9/...
# processing la-liga, season 2011-2012, stage Week10
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/10/...
# processing la-liga, season 2011-2012, stage Week11
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/11/...
# processing la-liga, season 2011-2012, stage Week12
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/12/...
# processing la-liga, season 2011-2012, stage Week13
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/13/...
# processing la-liga, season 2011-2012, stage Week14
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/14/...
# processing la-liga, season 2011-2012, stage Week15
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/15/...
# processing la-liga, season 2011-2012, stage Week16
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/16/...
# processing la-liga, season 2011-2012, stage Week17
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/17/...
# processing la-liga, season 2011-2012, stage Week18
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/18/...
# processing la-liga, season 2011-2012, stage Week19
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/19/...
# processing la-liga, season 2011-2012, stage Week20
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/20/...
# processing la-liga, season 2011-2012, stage Week21
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/21/...
# processing la-liga, season 2011-2012, stage Week22
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/22/...
# processing la-liga, season 2011-2012, stage Week23
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/23/...
# processing la-liga, season 2011-2012, stage Week24
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/24/...
# processing la-liga, season 2011-2012, stage Week25
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/25/...
# processing la-liga, season 2011-2012, stage Week26
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/26/...
# processing la-liga, season 2011-2012, stage Week27
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/27/...
# processing la-liga, season 2011-2012, stage Week28
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/28/...
# processing la-liga, season 2011-2012, stage Week29
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/29/...
# processing la-liga, season 2011-2012, stage Week30
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/30/...
# processing la-liga, season 2011-2012, stage Week31
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/31/...
# processing la-liga, season 2011-2012, stage Week32
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/32/...
# processing la-liga, season 2011-2012, stage Week33
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/33/...
# processing la-liga, season 2011-2012, stage Week34
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/34/...
# processing la-liga, season 2011-2012, stage Week35
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/35/...
# processing la-liga, season 2011-2012, stage Week36
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/36/...
# processing la-liga, season 2011-2012, stage Week37
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/37/...
# processing la-liga, season 2011-2012, stage Week38
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2011-2012-spieltag/38/...
# --------------------------------
# processing season 2010-2011
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/38/...
# processing la-liga, season 2010-2011, stage Week01
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/1/...
# processing la-liga, season 2010-2011, stage Week02
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/2/...
# processing la-liga, season 2010-2011, stage Week03
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/3/...
# processing la-liga, season 2010-2011, stage Week04
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/4/...
# processing la-liga, season 2010-2011, stage Week05
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/5/...
# processing la-liga, season 2010-2011, stage Week06
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/6/...
# processing la-liga, season 2010-2011, stage Week07
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/7/...
# processing la-liga, season 2010-2011, stage Week08
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/8/...
# processing la-liga, season 2010-2011, stage Week09
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/9/...
# processing la-liga, season 2010-2011, stage Week10
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/10/...
# processing la-liga, season 2010-2011, stage Week11
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/11/...
# processing la-liga, season 2010-2011, stage Week12
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/12/...
# processing la-liga, season 2010-2011, stage Week13
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/13/...
# processing la-liga, season 2010-2011, stage Week14
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/14/...
# processing la-liga, season 2010-2011, stage Week15
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/15/...
# processing la-liga, season 2010-2011, stage Week16
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/16/...
# processing la-liga, season 2010-2011, stage Week17
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/17/...
# processing la-liga, season 2010-2011, stage Week18
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/18/...
# processing la-liga, season 2010-2011, stage Week19
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/19/...
# processing la-liga, season 2010-2011, stage Week20
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/20/...
# processing la-liga, season 2010-2011, stage Week21
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/21/...
# processing la-liga, season 2010-2011, stage Week22
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/22/...
# processing la-liga, season 2010-2011, stage Week23
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/23/...
# processing la-liga, season 2010-2011, stage Week24
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/24/...
# processing la-liga, season 2010-2011, stage Week25
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/25/...
# processing la-liga, season 2010-2011, stage Week26
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/26/...
# processing la-liga, season 2010-2011, stage Week27
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/27/...
# processing la-liga, season 2010-2011, stage Week28
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/28/...
# processing la-liga, season 2010-2011, stage Week29
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/29/...
# processing la-liga, season 2010-2011, stage Week30
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/30/...
# processing la-liga, season 2010-2011, stage Week31
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/31/...
# processing la-liga, season 2010-2011, stage Week32
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/32/...
# processing la-liga, season 2010-2011, stage Week33
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/33/...
# processing la-liga, season 2010-2011, stage Week34
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/34/...
# processing la-liga, season 2010-2011, stage Week35
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/35/...
# processing la-liga, season 2010-2011, stage Week36
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/36/...
# processing la-liga, season 2010-2011, stage Week37
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/37/...
# processing la-liga, season 2010-2011, stage Week38
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2010-2011-spieltag/38/...
# --------------------------------
# processing season 2009-2010
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/38/...
# processing la-liga, season 2009-2010, stage Week01
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/1/...
# processing la-liga, season 2009-2010, stage Week02
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/2/...
# processing la-liga, season 2009-2010, stage Week03
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/3/...
# processing la-liga, season 2009-2010, stage Week04
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/4/...
# processing la-liga, season 2009-2010, stage Week05
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/5/...
# processing la-liga, season 2009-2010, stage Week06
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/6/...
# processing la-liga, season 2009-2010, stage Week07
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/7/...
# processing la-liga, season 2009-2010, stage Week08
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/8/...
# processing la-liga, season 2009-2010, stage Week09
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/9/...
# processing la-liga, season 2009-2010, stage Week10
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/10/...
# processing la-liga, season 2009-2010, stage Week11
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/11/...
# processing la-liga, season 2009-2010, stage Week12
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/12/...
# processing la-liga, season 2009-2010, stage Week13
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/13/...
# processing la-liga, season 2009-2010, stage Week14
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/14/...
# processing la-liga, season 2009-2010, stage Week15
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/15/...
# processing la-liga, season 2009-2010, stage Week16
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/16/...
# processing la-liga, season 2009-2010, stage Week17
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/17/...
# processing la-liga, season 2009-2010, stage Week18
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/18/...
# processing la-liga, season 2009-2010, stage Week19
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/19/...
# processing la-liga, season 2009-2010, stage Week20
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/20/...
# processing la-liga, season 2009-2010, stage Week21
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/21/...
# processing la-liga, season 2009-2010, stage Week22
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/22/...
# processing la-liga, season 2009-2010, stage Week23
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/23/...
# processing la-liga, season 2009-2010, stage Week24
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/24/...
# processing la-liga, season 2009-2010, stage Week25
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/25/...
# processing la-liga, season 2009-2010, stage Week26
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/26/...
# processing la-liga, season 2009-2010, stage Week27
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/27/...
# processing la-liga, season 2009-2010, stage Week28
# Trying to load url https://www.worldfootball.net/schedule/esp-primera-division-2009-2010-spieltag/28/...
# ...
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2007-2008-3-runde/2/...
# processing uefa-intertoto-cup, season 2007-2008, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2007-2008-1-runde/0/...
# processing uefa-intertoto-cup, season 2007-2008, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2007-2008-2-runde/0/...
# processing uefa-intertoto-cup, season 2007-2008, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2007-2008-3-runde/0/...
# --------------------------------
# processing season 2006-2007
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2006-2007-3-runde/2/...
# processing uefa-intertoto-cup, season 2006-2007, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2006-2007-1-runde/0/...
# processing uefa-intertoto-cup, season 2006-2007, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2006-2007-2-runde/0/...
# processing uefa-intertoto-cup, season 2006-2007, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2006-2007-3-runde/0/...
# --------------------------------
# processing season 2005-2006
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2005-2006-endspiel/2/...
# processing uefa-intertoto-cup, season 2005-2006, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2005-2006-1-runde/0/...
# processing uefa-intertoto-cup, season 2005-2006, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2005-2006-2-runde/0/...
# processing uefa-intertoto-cup, season 2005-2006, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2005-2006-3-runde/0/...
# processing uefa-intertoto-cup, season 2005-2006, stage Semi-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2005-2006-halbfinale/0/...
# processing uefa-intertoto-cup, season 2005-2006, stage Final
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2005-2006-endspiel/0/...
# --------------------------------
# processing season 2004-2005
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2004-2005-finale/2/...
# processing uefa-intertoto-cup, season 2004-2005, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2004-2005-1-runde/0/...
# processing uefa-intertoto-cup, season 2004-2005, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2004-2005-2-runde/0/...
# processing uefa-intertoto-cup, season 2004-2005, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2004-2005-3-runde/0/...
# processing uefa-intertoto-cup, season 2004-2005, stage Semi-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2004-2005-halbfinale/0/...
# processing uefa-intertoto-cup, season 2004-2005, stage Final
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2004-2005-finale/0/...
# --------------------------------
# processing season 2003-2004
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2003-2004-endspiel/2/...
# processing uefa-intertoto-cup, season 2003-2004, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2003-2004-1-runde/0/...
# processing uefa-intertoto-cup, season 2003-2004, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2003-2004-2-runde/0/...
# processing uefa-intertoto-cup, season 2003-2004, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2003-2004-3-runde/0/...
# processing uefa-intertoto-cup, season 2003-2004, stage Semi-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2003-2004-halbfinale/0/...
# processing uefa-intertoto-cup, season 2003-2004, stage Final
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2003-2004-endspiel/0/...
# --------------------------------
# processing season 2002-2003
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2002-2003-endspiel/2/...
# processing uefa-intertoto-cup, season 2002-2003, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2002-2003-1-runde/0/...
# processing uefa-intertoto-cup, season 2002-2003, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2002-2003-2-runde/0/...
# processing uefa-intertoto-cup, season 2002-2003, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2002-2003-3-runde/0/...
# processing uefa-intertoto-cup, season 2002-2003, stage Semi-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2002-2003-halbfinale/0/...
# processing uefa-intertoto-cup, season 2002-2003, stage Final
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2002-2003-endspiel/0/...
# --------------------------------
# processing season 2001-2002
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2001-2002-endspiel/2/...
# processing uefa-intertoto-cup, season 2001-2002, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2001-2002-1-runde/0/...
# processing uefa-intertoto-cup, season 2001-2002, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2001-2002-2-runde/0/...
# processing uefa-intertoto-cup, season 2001-2002, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2001-2002-3-runde/0/...
# processing uefa-intertoto-cup, season 2001-2002, stage Semi-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2001-2002-halbfinale/0/...
# processing uefa-intertoto-cup, season 2001-2002, stage Final
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2001-2002-endspiel/0/...
# --------------------------------
# processing season 2000-2001
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2000-2001-5-runde/2/...
# processing uefa-intertoto-cup, season 2000-2001, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2000-2001-1-runde/0/...
# processing uefa-intertoto-cup, season 2000-2001, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2000-2001-2-runde/0/...
# processing uefa-intertoto-cup, season 2000-2001, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2000-2001-3-runde/0/...
# processing uefa-intertoto-cup, season 2000-2001, stage 4. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2000-2001-4-runde/0/...
# processing uefa-intertoto-cup, season 2000-2001, stage 5. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-2000-2001-5-runde/0/...
# --------------------------------
# processing season 1999-2000
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1999-2000-5-runde/2/...
# processing uefa-intertoto-cup, season 1999-2000, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1999-2000-1-runde/0/...
# processing uefa-intertoto-cup, season 1999-2000, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1999-2000-2-runde/0/...
# processing uefa-intertoto-cup, season 1999-2000, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1999-2000-3-runde/0/...
# processing uefa-intertoto-cup, season 1999-2000, stage 4. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1999-2000-4-runde/0/...
# processing uefa-intertoto-cup, season 1999-2000, stage 5. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1999-2000-5-runde/0/...
# --------------------------------
# processing season 1998-1999
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1998-1999-5-runde/2/...
# processing uefa-intertoto-cup, season 1998-1999, stage 1. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1998-1999-1-runde/0/...
# processing uefa-intertoto-cup, season 1998-1999, stage 2. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1998-1999-2-runde/0/...
# processing uefa-intertoto-cup, season 1998-1999, stage 3. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1998-1999-3-runde/0/...
# processing uefa-intertoto-cup, season 1998-1999, stage 4. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1998-1999-4-runde/0/...
# processing uefa-intertoto-cup, season 1998-1999, stage 5. Round
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1998-1999-5-runde/0/...
# --------------------------------
# processing season 1997-1998
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-finale/2/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 1
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-1/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 2
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-2/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 3
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-3/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 4
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-4/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 5
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-5/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 6
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-6/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 7
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-7/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 8
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-8/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 9
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-9/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 10
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-10/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 11
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-11/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Group 12
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-gruppe-12/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Semi-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-halbfinale/0/...
# processing uefa-intertoto-cup, season 1997-1998, stage Final
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1997-1998-finale/0/...
# --------------------------------
# processing season 1996-1997
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-finale/2/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 1
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-1/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 2
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-2/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 3
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-3/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 4
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-4/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 5
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-5/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 6
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-6/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 7
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-7/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 8
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-8/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 9
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-9/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 10
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-10/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 11
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-11/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Group 12
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-gruppe-12/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Semi-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-halbfinale/0/...
# processing uefa-intertoto-cup, season 1996-1997, stage Final
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1996-1997-finale/0/...
# --------------------------------
# processing season 1995-1996
# --------------------------------
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-halbfinale/2/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 1
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-1/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 2
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-2/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 3
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-3/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 4
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-4/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 5
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-5/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 6
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-6/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 7
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-7/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 8
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-8/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 9
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-9/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 10
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-10/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 11
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-11/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Group 12
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-gruppe-12/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Round of 16
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-achtelfinale/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Quarter-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-viertelfinale/0/...
# processing uefa-intertoto-cup, season 1995-1996, stage Semi-finals
# Trying to load url https://www.worldfootball.net/schedule/ui-cup-1995-1996-halbfinale/0/...
# Process finished
